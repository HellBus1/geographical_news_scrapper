# %% [markdown]
# # Data Preparation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# dataset = pd.read_csv("/content/drive/MyDrive/NER_v2.2/dataset_ner/df_total.csv")
dataset = pd.read_csv("/content/drive/MyDrive/NER_v2.2/dataset_ner/dataset_tagged_bow.csv")
# for x in dataset['BIO_tag_0']:
#   print(x)
prepositions = ['selatan', 'tenggara', 'timur', 'utara', ]
dataset.head()
# Out:
#   token_0 BIO_tag_0
# 0    aceh       NaN
# 1       ,         O
# 2   barat       NaN
# 3       ,         O
# 4    aceh       NaN
