# %%
import pandas as pd
import re
import string
from custom_stemmer import CustomStemmer
import swifter

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
class CustomStemmer:
  def __init__(self, tweet_data):
      self.factory = StemmerFactory()
      self.stemmer = self.factory.create_stemmer()
      self.term_dict = {}
      for document in tweet_data:
        for term in document:
          if term not in self.term_dict:
            self.term_dict[term] = ''

      for term in self.term_dict:
        self.term_dict[term] = self.stemmed_wrapper(term)
        print(term,":" , self.term_dict[term])

  def stemmed_wrapper(self, term):
    return self.stemmer.stem(term)

  def get_stemmed_term(self, document):
    return [self.term_dict[term] for term in document]

# %%
# ----- Tokenizing -----
def remove_news_special(text):
  # remove tab, new line, and back slice
  text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
  # remove non ASCII (emoticon, kanji, .etc)
  text = text.encode('ascii', 'replace').decode('ascii')
  # remove mention, link, hashtag
  text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
  # remove incomplete url
  return text.replace("http://", " ").replace("https://", " ")

#remove number
def remove_number(text):
  return re.sub(r"\d+", "", text)

#remove punctuation
def remove_punctuation(text):
  return text.translate(str.maketrans("", "", string.punctuation))

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
  return text.strip()

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

#remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

#NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

#NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

def stopwords_removal(words):
  list_stopwords = stopwords.words('indonesian')
  list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])
  list_stopwords = set(list_stopwords)

  return [word for word in words if word not in list_stopwords]

nltk.download('punkt')
news_data = pd.read_csv("scrapped_news.csv", encoding = "ISO-8859-1")
# print(news_data['description'].isnull())
# print(news_data['description'].isnull())
news_data['description'] = news_data['description'].apply(remove_news_special)
# news_data['description'] = news_data['description'].apply(remove_number)
news_data['description'] = news_data['description'].apply(remove_punctuation)
news_data['description'] = news_data['description'].apply(remove_whitespace_LT)
news_data['description'] = news_data['description'].apply(remove_whitespace_multiple)
news_data['description'] = news_data['description'].apply(remove_single_char)
news_data['description_tokens'] = news_data['description'].apply(word_tokenize_wrapper)
news_data['description_tokens_fdist'] = news_data['description_tokens'].apply(freqDist_wrapper)
news_data['description_tokens_wsw'] = news_data['description_tokens'].apply(freqDist_wrapper)

stemmer = CustomStemmer(news_data['description_tokens_wsw'])
news_data['description_tokens_stemmed'] = news_data['description_tokens_wsw'].swifter.apply(stemmer.get_stemmed_term)
# We will skip normalization word 

news_data.to_csv('text_preprocessing.csv')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/syubbanfakhriya/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# yang : yang
# di : di
# air : air
# saya : saya
# dan : dan
# itu : itu
# rumah : rumah
# ke : ke
# Desa : desa
# banjir : banjir
# saluran : salur
# Sunarti : sunarti
# dalam : dalam
# pun : pun
# saat : saat
# ada : ada
# kawasan : kawasan
# cucunya : cucu
# deras : deras
# dari : dari
# Jatinangor : jatinangor
# kecil : kecil
# merendam : rendam
# tol : tol
# luapan : luap
# Banjir : banjir
# menerjang : terjang
# Sumedang : sumedang
# warga : warga
# Cipacing : cipacing
# rumahnya : rumah
# ia : ia
# bersama : sama
# masih : masih
# kemudian : kemudian
# semua : semua
# cucu : cucu
# satu : satu
# tidak : tidak
# berada : ada
# juga : juga
# untuk : untuk
# Saat : saat
# pada : pada
# Jumat : jumat
# 24122021 : 24122021
# bagi : bagi
# sedang : sedang
# masuk : masuk
# mengaji : aji
# ungkapnya : ungkap
# sampai : sampai
# bisa : bisa
# terendam : rendam
# lebih : lebih
# meter : meter
# tersebut : sebut
# dua : dua
# hujan : hujan
# bawahnya : bawah
# terjadi : jadi
# Cileles : cileles
# sempat : sempat
# akan : akan
# beberapa : beberapa
# para : para
# petani : tani
# lahan : lahan
# desa : desa
# sore : sore
# Salah : salah
# satunya : satu
# oleh : oleh
# setelah : telah
# ashar : ashar
# tibatiba : tibatiba
# dengan : dengan
# hanya : hanya
# sekali : sekali
# kepada : kepada
# membuka : buka
# pintu : pintu
# depan : depan
# lantaran : lantar
# begitu : begitu
# Pokoknya : pokok
# lihat : lihat
# airnya : air
# barang : barang
# kurang : kurang
# 2 : 2
# langsung : langsung
# berlari : lari
# tidur : tidur
# tempat : tempat
# Ia : ia
# belakang : belakang
# naik : naik
# atas : atas
# genteng : genteng
# toren : toren
# tinggal : tinggal
# orang : orang
# anaknya : anak
# lain : lain
# telah : telah
# anak : anak
# karena : karena
# kebetulan : betul
# sementara : sementara
# menjadi : jadi
# banyak : banyak
# kalau : kalau
# selain : selain
# akibat : akibat
# Cisumdawu : cisumdawu
# Kabupaten : kabupaten
# Herman : herman
# sana : sana
# tiga : tiga
# kita : kita
# Satker : satker
# memperbaiki : baik
# sehingga : sehingga
# mengakibatkan : akibat
# peristiwa : peristiwa
# 4 : 4
# sawah : sawah
# sejumlah : jumlah
# Cikeruh : cikeruh
# Sayang : sayang
# solusi : solusi
# embung : embung
# Hujan : hujan
# mengguyur : guyur
# ini : ini
# diantaranya : antara
# Cerita : cerita
# Cucunya : cucu
# Naik : naik
# Genteng : genteng
# Terjang : terjang
# menyisakan : sisa
# trauma : trauma
# dialami : alami
# Warga : warga
# membaca : baca
# AlQuran : alquran
# melaksanakan : laksana
# sholat : sholat
# dikejutkan : kejut
# keberadaan : ada
# seorang : orang
# Kejadiannya : jadi
# mendadak : dadak
# habis : habis
# shalat : shalat
# baru : baru
# pertengahan : tengah
# surat : surat
# ArRahman : arrahman
# mukena : mukena
# basah : basah
# Lalu : lalu
# bergegas : gegas
# penasaran : penasaran
# ingin : ingin
# tahu : tahu
# darimana : darimana
# datangnya : datang
# aliran : alir
# Namun : namun
# tanpa : tanpa
# disangka : sangka
# secepat : cepat
# kilat : kilat
# pas : pas
# saking : saking
# sangat : sangat
# barangbarang : barangbarang
# mengambang : ambang
# elektronik : elektronik
# termasuk : masuk
# motor : motor
# paparnya : papar
# Sebelum : belum
# setinggi : setinggi
# arah : arah
# sedari : dar
# tadi : tadi
# Tanpa : tanpa
# pikir : pikir
# panjang : panjang
# memboyong : boyong
# Dengan : dengan
# susah : susah
# payah : payah
# kala : kala
# sambil : sambil
# menggendong : gendong
# melalui : lalu
# instalasi : instalasi
# Saya : saya
# bopong : bopong
# lagi : lagi
# lewat : lewat
# akhirnya : akhir
# tolong : tolong
# tetangga : tetangga
# terangnya : terang
# Sekadar : sekadar
# diketahui : tahu
# suaminya : suami
# buah : buah
# hati : hati
# dimilikinya : milik
# Sementara : sementara
# terpisah : pisah
# sudah : sudah
# menikah : meni
# memiliki : milik
# kejadian : jadi
# main : main
# suami : suami
# luar : luar
# salah : salah
# luput : luput
# maut : maut
# bandang : bandang
# keluarganya : keluarga
# berbuat : buat
# bah : bah
# seluruh : seluruh
# harta : harta
# bendanya : benda
# kepala : kepala
# menyelamatkan : selamat
# biarkan : biar
# cepat : cepat
# naiknya : naik
# pungkasnya : pungkas
# Berita : berita
# sebelumnya : belum
# Penyebab : sebab
# melanda : landa
# sekitarnya : sekitar
# diduga : duga
# sistem : sistem
# Hal : hal
# dikatakan : kata
# Sekretaris : sekretaris
# Daerah : daerah
# Suryatman : suryatman
# meninjau : tinjau
# lokasi : lokasi
# Sabtu : sabtu
# 25122021 : 25122021
# Kita : kita
# jalan : jalan
# besar : besar
# saja : saja
# simpulkan : simpul
# membutuh : butuh
# treatment : treatment
# analisis : analisis
# awal : awal
# ujar : ujar
# Menurutnya : turut
# kondisi : kondisi
# serupa : rupa
# Beberapa : beberapa
# mengalir : alir
# terjadinya : jadi
# Saluran : salur
# ukurannya : ukur
# otomatis : otomatis
# setiap : tiap
# katanya : kata
# Akibat : akibat
# hektar : hektar
# tergenang : genang
# terancam : ancam
# longsor : longsor
# bantaran : bantaran
# sungai : sungai
# Terparah : parah
# RW : rw
# Untuk : untuk
# waktu : waktu
# terlalu : terlalu
# lama : lama
# pihak : pihak
# mencari : cari
# pertama : pertama
# salurannya : salur
# diperbaiki : baik
# mengembalikan : kembali
# fungsi : fungsi
# penampung : tampung
# ujarnya : ujar
# Kades : kades
# Duduy : duduy
# Abdul : abdul
# Holik : holik
# mengatakan : kata
# pihaknya : pihak
# menyampaikan : sampai
# melakukan : laku
# normalisasi : normalisasi
# jangka : jangka
# pendek : pendek
# pembangunan : bangun
# meminimalisir : meminimalisir
# debit : debit
# jika : jika
# turun : turun
# setahun : tahun
# infrastruktur : infrastruktur
# rusak : rusak
# TPT : tpt
# titik : titik
# roboh : roboh
# irigasi : irigasi
# jebol : jebol
# diharapkan : harap
# pemerintah : perintah
# memperhartikan : memperhartikan
# kami : kami
# berharap : harap
# adanya : ada
# kompensasi : kompensasi
# pesawahannya : sawah
# terkena : kena
# dampak : dampak
# Pasalnya : pasal
# pesawahan : sawah
# tumpuan : tumpu
# hidup : hidup
# Karena : karena
# pertanian : tani
# makan : makan
# jadi : jadi
# gagal : gagal
# panen : panen
# maka : maka
# kasihan : kasihan
# ucapnya : ucap
# wilayah : wilayah
# Kecamatan : camat
# Tidak : tidak
# korban : korban
# jiwa : jiwa
# namun : namun
# ratusan : ratus
# ketinggian : tinggi
# hingga : hingga
# mencapai : capai
# 1 : 1
# Tiga : tiga
# yakni : yakni
# terparah : parah
# diterjang : terjang
# disertai : serta
# lumpur : lumpur
# Padangsidimpuan : padangsidimpuan
# ULP : ulp
# Angkola : angkola
# Kota : kota
# UP3 : up3
# Yusuf : yusuf
# Batang : batang
# PLN : pln
# listrik : listrik
# bencana : bencana
# Sangkunur : sangkunur
# Toru : toru
# TapselMadina : tapselmadina
# Selesai : selesai
# Selatan : selatan
# Natal : natal
# kata : kata
# Unit : unit
# kerusakan : rusa
# pelanggan : langgan
# masingmasing : masingmasing
# tim : tim
# Wayu : wayu
# masyarakat : masyarakat
# gangguan : ganggu
# merupakan : rupa
# Perbaikan : baik
# Listrik : listrik
# Terimbas : imbas
# LongsongBanjir : longsongbanjir
# selesaikan : selesai
# perbaikan : baik
# Tapanuli : tapanuli
# Mandailing : mandailing
# Madina : madina
# Diperbaiki : baik
# Jaringan : jaring
# mati : mati
# Telah : telah
# 100 : 100
# persen : persen
# pulihkan : pulih
# Manager : manager
# Pelaksana : laksana
# Pelayanan : layan
# Pelanggan : langgan
# Hadiyanto : hadiyanto
# wartawan : wartawan
# menyebut : sebut
# tanah : tanah
# menyebabkan : sebab
# 462 : 462
# unit : unit
# trafo : trafo
# Berimbas : imbas
# putusnya : putus
# 30346 : 30346
# menjelaskan : jelas
# area : area
# layanan : layan
# dibawah : bawah
# Keempatnya : empat
# yaitu : yaitu
# Kotanopan : kotanopan
# Panyabungan : panyabungan
# Sidimpuan : sidimpuan
# Proses : proses
# perbaikannya : baik
# dilakukan : laku
# siang : siang
# malam : malam
# teknisi : teknisi
# Uang : uang
# disupervisi : supervisi
# memastikan : pasti
# percepatan : cepat
# recovery : recovery
# menurunkan : turun
# sebagai : bagai
# pelaksana : laksana
# supervisi : supervisi
# Manajer : manajer
# Dwiafridho : dwiafridho
# rasa : rasa
# terima : terima
# kasihnya : kasih
# bersabar : sabar
# Wilayah : wilayah
# paling : paling
# terdapak : terdapak
# membawahi : bawah
# Padangsidempuan : padangsidempuan
# 7 : 7
# Tapsel : tapsel
# Yakni : yakni
# Barat : barat
# Muara : muara
# Marancar : marancar
# Bencana : bencana
# Dimana : mana
# kali : kali
# Apabila : apabila
# menemukan : temu
# silahkan : silah
# melapor : lapor
# aplikasi : aplikasi
# Mobile : mobile
# atau : atau
# Call : call
# Center : center
# 123 : 123
# sekitar : sekitar
# Palembang : palembang
# Irwan : irwan
# wanita : wanita
# hilang : hilang
# terseret : seret
# arus : arus
# Kalidoni : kalidoni
# tahun : tahun
# menggenangi : genang
# Iya : iya
# pukul : pukul
# WIB : wib
# ditemukan : temu
# Kapolsek : kapolsek
# AKP : akp
# Sidik : sidik
# dimintai : minta
# konfirmasi : konfirmasi
# Korban : korban
# 20 : 20
# Identitas : identitas
# jenis : jenis
# Vario : vario
# dia : dia
# Mapolsek : mapolsek
# Dari : dari
# berusia : usia
# 40 : 40
# dibawa : bawa
# RS : rs
# Bhayangkara : bhayangkara
# hampir : hampir
# kecamatan : camat
# goronggorong : goronggorong
# Peristiwa : peristiwa
# berangkat : berangkat
# pasar : pasar
# Wanita : wanita
# Hilang : hilang
# Terseret : seret
# Ditemukan : temu
# Tewas : tewas
# Seorang : orang
# tenggelam : tenggelam
# sekira : sekira
# 1409 : 1409
# menyelidiki : selidik
# identitas : identitas
# selidiki : selidik
# TKP : tkp
# Motor : motor
# diamankan : aman
# ciriciri : ciriciri
# fisik : fisik
# visum : visum
# Barang : barang
# bukti : bukti
# amankan : aman
# identifikasi : identifikasi
# fisiknya : fisik
# Selanjutnya : lanjut
# divisum : visum
# jelasnya : jelas
# Sebelumnya : belum
# informasinya : informasi
# benar : benar
# usia : usia
# 4050 : 4050
# ketika : ketika
# meluap : luap
# disebut : sebut
# tengah : tengah
# mengendarai : kendara
# sepeda : sepeda
# 0500 : 0500
# menduga : duga
# hendak : hendak
# Informasinya : informasi
# kejadiannya : jadi
# jam : jam
# 5 : 5
# Subuh : subuh
# Ibu : ibu
# mau : mau
# pakai : pakai
# Tapi : tapi
# sewaktu : waktu
# Motornya : motor
# ketemu : ketemu
# tapi : tapi
# dianya : dia
# ungkap : ungkap
# Johan : johan
# ditemui : temu
# nahas : nahas
# Kenten : kenten
# Permai : permai
# Hingga : hingga
# gabungan : gabung
# setempat : tempat
# SAR : sar
# nasional : nasional
# TNI : tni
# Polri : polri
# pencarian : cari
# terhadap : hadap
# belum : belum
# Sekedar : dar
# informasi : informasi
# Sumatera : sumatera
# Sumsel : sumsel
# sejak : sejak
# dini : dini
# hari : hari
# Belum : belum
# data : data
# pasti : pasti
# berapa : berapa
# tinggi : tinggi
# tak : tak
# permukiman : mukim
# Sejumlah : jumlah
# protokol : protokol
# bahkan : bahkan
# dinas : dinas
# Wali : wali
# digenangi : genang
# daerah : daerah
# bukan : bukan
# langganan : langgan
# lebat : lebat
# Herry : herry
# Cibeusi : cibeusi
# parah : parah
# surut : surut
# sendiri : sendiri
# Sistem : sistem
# Air : air
# Tol : tol
# Disinyalir : sinyalir
# Jadi : jadi
# Seperti : seperti
# diberitakan : berita
# terlihat : lihat
# membersihkan : bersih
# miliknya : milik
# Bahkan : bahkan
# selutut : lutut
# dewasa : dewasa
# sebuah : buah
# masjid : masjid
# ikut : ikut
# besarnya : besar
# Camat : camat
# Dewantara : dewantara
# lainnya : lain
# banjirnya : banjir
# disini : sini
# detikcom : detikcom
# menyebutkan : sebut
# sedikitnya : sedikit
# Tinggi : tinggi
# diakibatkan : akibat
# meluapnya : luap
# alirannya : alir
# darimanamana : darimanamana
# Sukasari : sukasari
# Tanjngsari : tanjngsari
# Sinta : sinta
# musim : musim
# BMKG : bmkg
# curah : curah
# tetap : tetap
# harus : harus
# kemarin : kemarin
# Curah : curah
# 31 : 31
# bulan : bulan
# sepanjang : panjang
# puncak : puncak
# JanuariMaret : januarimaret
# Potensi : potensi
# diwaspadai : waspada
# cuaca : cuaca
# sampaikan : sampai
# peringatan : ingat
# BPBD : bpbd
# lima : lima
# BNPB : bnpb
# Pemicu : picu
# Tertinggi : tinggi
# Sejak : sejak
# Tahun : tahun
# Terakhir : akhir
# tercatat : catat
# Staklim : staklim
# sebesar : besar
# 1597 : 1597
# mm : mm
# Ini : ini
# adalah : adalah
# rekor : rekor
# tertinggi : tinggi
# Desember : desember
# terakhir : akhir
# Adapun : adapun
# catatan : catat
# klimatologis : klimatolog
# mengimbau : imbau
# agar : agar
# waspada : waspada
# Sebab : sebab
# sebut : sebut
# memprediksi : prediksi
# 2022 : 2022
# biasa : biasa
# imbau : imbau
# Lebih : lebih
# lanjut : lanjut
# menuturkan : tutur
# potensi : potensi
# meminta : minta
# mempersiapkan : siap
# segala : segala
# sesuatunya : sesuatu
# seperti : seperti
# Masyarakat : masyarakat
# bersiapsiap : bersiapsiap
# 22 : 22
# Oktober : oktober
# lalu : lalu
# imbuhnya : imbuh
# Memang : memang
# Indonesia : indonesia
# umumnya : umum
# cukup : cukup
# selalu : selalu
# kewaspadaan : waspada
# kemarau : kemarau
# pancaroba : pancaroba
# sambungnya : sambung
# Terkait : kait
# mengepung : kepung
# menurut : turut
# kembali : kembali
# apabila : apabila
# antisipasi : antisipasi
# Dia : dia
# disampaikan : sampai
# roadshow : roadshow
# Lamina : lamina
# aktif : aktif
# khawatirkan : khawatir
# menambah : tambah
# koordinasi : koordinasi
# medsos : medsos
# media : media
# tutur : tutur
# seusai : usai
# penyebabnya : sebab
# Menurut : turut
# laporan : lapor
# wilayahnya : wilayah
# intensitas : intensitas
# Sungai : sungai
# Musi : mus
# Kondisi : kondisi
# diperburuk : buruk
# faktor : faktor
# drainase : drainase
# kota : kota
# optimal : optimal
# Kepala : kepala
# Pusat : pusat
# Data : data
# Informasi : informasi
# Komunikasi : komunikasi
# Kebencanaan : bencana
# Muhari : muhari
# keterangannya : terang
# Minggu : minggu
# 2612 : 2612
# 2512 : 2512
# 0400 : 0400
# ketinggiannya : tinggi
# terpantau : pantau
# 60 : 60
# sentimeter : sentimeter
# terdampak : dampak
# gempa : gempa
# Sorong : sorong
# 45 : 45
# tulis : tulis
# Kekuatan : kuat
# dirasakan : rasa
# MMI : mmi
# III : iii
# getaran : getar
# Gempa : gempa
# Guncang : guncang
# Papua : papua
# berkekuatan : kuat
# magnitudo : magnitudo
# mengguncang : guncang
# Badan : badan
# Meteorologi : meteorologi
# Klimatologi : klimatologi
# Geofisika : geofisika
# melaporkan : lapor
# Kamis : kamis
# 23122021 : 23122021
# 1113 : 1113
# kedalaman : dalam
# kilometer : kilometer
# Laut : laut
# km : km
# timur : timur
# laut : laut
# Titik : titik
# pusat : pusat
# dilaporkan : lapor
# koordinat : koordinat
# 066 : 066
# Lintang : lintang
# LS : ls
# 13158 : 13158
# Bujur : bujur
# Timur : timur
# BT : bt
# artinya : arti
# nyata : nyata
# Terasa : asa
# seakanakan : seakanakan
# truk : truk
# berlalu : lalu
# Hatihati : hatihati
# gempabumi : gempabumi
# susulan : susul
# mungkin : mungkin
# dosen : dosen
# meninggal : tinggal
# dunia : dunia
# Dosen : dosen
# Ketinggian : tinggi
# Raden : raden
# Fatah : fatah
# Azili : azili
# tersengat : sengat
# Sukarami : sukarami
# memang : memang
# UIN : uin
# Malang : malang
# UINWanita : uinwanita
# Hanyut : hanyut
# Landa : landa
# tangan : tangan
# penanganan : tangan
# rata : rata
# menyebar : sebar
# evakuasi : evakuasi
# kegiatan : giat
# mobilitas : mobilitas
# Kabid : kabid
# Penanganan : tangan
# Kedaruratan : darurat
# Ansori : ansori
# bervariasi : variasi
# Universitas : universitas
# Islam : islam
# Negeri : negeri
# 53 : 53
# tewas : tewas
# kediamannya : diam
# pagi : pagi
# Infonya : info
# Fadly : fadly
# Pihak : pihak
# memberikan : beri
# tanggapan : tanggap
# membenarkan : benar
# dosennya : dosen
# Kabar : kabar
# duka : duka
# Pak : pak
# senior : senior
# PNS : pns
# Fakultas : fakultas
# Syariah : syariah
# Hukum : hukum
# Humas : humas
# Elis : elis
# dihubungi : hubung
# lintas : lintas
# Marwiansyah : marwiansyah
# Jambi : jambi
# roda : roda
# melintas : lintas
# dapat : dapat
# kendaraan : kendara
# Jalan : jalan
# Lintas : lintas
# Merlung : merlung
# Tanjabbar : tanjabbar
# empat : empat
# diminta : minta
# menunggu : tunggu
# kemacetan : macet
# Perbatasan : batas
# Kebanjiran : banjir
# Usai : usai
# Deras : deras
# Tengah : tengah
# Tanjung : tanjung
# Jabung : jabung
# disebabkan : sebab
# semalam : malam
# menuju : tuju
# Tebo : tebo
# terkendala : kendala
# cara : cara
# menyeberangi : rang
# menggunakan : guna
# rakit : rakit
# dibuat : buat
# Sejauh : jauh
# melintasi : lintas
# terlebih : lebih
# dahulu : dahulu
# genangan : genang
# Kalau : kalau
# teredam : redam
# Ada : ada
# akses : akses
# kini : kini
# terpaksa : paksa
# dulu : dulu
# perkirakan : kira
# kemungkinan : mungkin
# dilalui : lalu
# berdasarkan : dasar
# keterangan : terang
# lalang : lalang
# padat : padat
# meski : meski
# momen : momen
# libur : libur
# Sampai : sampai
# jalur : jalur
# dipadati : padat
# aman : aman
# lancar : lancar
# Hanya : hanya
# mobil : mobil
# 0800 : 0800
# Polisi : polisi
# berjagajaga : berjagajaga
# memantau : pantau
# Jember : jember
# KM : km
# Bumi : bumi
# 18 : 18
# 112202 : 112202
# Info : info
# Mag : mag
# guncang : guncang
# Koordinator : koordinator
# Mitigasi : mitigasi
# Tsunami : tsunami
# Daryono : daryono
# twitter : twitter
# dilihat : lihat
# 39 : 39
# Daya : daya
# Jawa : jawa
# tambahnya : tambah
# Nganjuk : nganjuk
# 35 : 35
# Sempat : sempat
# Magnitudo : magnitudo
# 1639 : 1639
# Mag35 : mag35
# SR : sr
# 24Dec21 : 24dec21
# 163928 : 163928
# StageofSleman : stageofsleman
# akun : akun
# twitternya : twitternya
# berlokasi : lokasi
# 746 : 746
# LS11193 : ls11193
# 16 : 16
# mempunyai : punya
# 206 : 206
# bumi : bumi
# tektonik : tektonik
# dibedakan : beda
# kedalamannya : dalam
# apa : apa
# Selain : selain
# tekanan : tekan
# lempengan : lempeng
# penyebab : sebab
# Berikut : ikut
# 3 : 3
# biasanya : biasa
# perbatasan : batas
# Tektonik : tektonik
# Terjadi : jadi
# Apa : apa
# Perbedaanya : perbedaanya
# Lain : lain
# penting : penting
# guncangan : guncang
# permukaan : muka
# pergerakan : gera
# kerak : kerak
# lempeng : lempeng
# letusan : letus
# gunung : gunung
# api : api
# Simak : simak
# berikut : ikut
# menjawab : jawab
# pertanyaan : tanya
# pelepasan : lepas
# energi : energi
# dihasilkan : hasil
# bergerak : gerak
# Semakin : makin
# kian : kian
# membesar : besar
# keadaan : ada
# mana : mana
# ditahan : tahan
# pinggiran : pinggir
# Pada : pada
# itulah : itu
# lempenganlempengan : lempenganlempengan
# kompresional : kompresional
# translasional : translasional
# sebenarnya : benar
# jenisjenis : jenisjenis
# Jenis : jenis
# Berdasarkan : dasar
# mengenai : kena
# rangkum : rangkum
# terkait : kait
# Samosir : samosir
# 26 : 26
# Utara : utara
# darat : darat
# II : ii
# Darat : darat
# Sumut : sumut
# Senin : senin
# 20122021 : 20122021
# 2141 : 2141
# tenggara : tenggara
# 258 : 258
# LU : lu
# 9886 : 9886
# Parapat : parapat
# bendabenda : bendabenda
# ringan : ringan
# digantung : gantung
# bergoyang : goyang
# pemda : pemda
# Kelurahan : lurah
# Lubuk : lubuk
# Kambing : kambing
# pernah : pernah
# puluhan : puluh
# kantor : kantor
# Jalanan : jalan
# Juga : juga
# Genangi : genang
# Puluhan : puluh
# Rumah : rumah
# Lokasi : lokasi
# mulai : mulai
# 15 : 15
# mengungsi : ungsi
# kerabatnya : kerabat
# Marwiyansyah : marwiyansyah
# sediki : dik
# tergenangi : genang
# Apalagi : apalagi
# terus : terus
# dataran : datar
# tetapi : tetapi
# Beruntung : untung
# kerugian : rugi
# materiil : materiil
# terdata : data
# Kantor : kantor
# Danau : danau
# polisi : polisi
# mengetahui : tahu
# beda : beda
# kelurahan : lurah
# info : info
# terkini : kini
# memasang : pasang
# tenda : tenda
# darurat : darurat
# buat : buat
# Bantuan : bantu
# sembako : sembako
# rencana : rencana
# disalurkan : salur
# esok : esok
# Wakil : wakil
# Bupati : bupati
# pejabat : jabat
# mengunjungi : unjung
# bertahan : tahan
# Rambah : rambah
# Rokan : rok
# Hulu : hulu
# Riau : riau
# Wimpi : wimpi
# Khusus : khusus
# keluarga : keluarga
# cm : cm
# dapur : dapur
# Edy : edy
# Pawan : pawan
# Ribuan : ribu
# umum : umum
# tahap : tahap
# kordinasi : kordinasi
# Diguyur : guyur
# Terendam : rendam
# terdapat : dapat
# tingginya : tinggi
# terang : terang
# Kapolres : kapolres
# AKBP : akbp
# Wimpiyanto : wimpiyanto
# Ujung : ujung
# Batu : batu
# Samo : samo
# 600 : 600
# Total : total
# ribuan : ribu
# Tetapi : tetapi
# antara : antara
# 80100 : 80100
# Babusalam : babusalam
# 0200 : 0200
# Bersama : sama
# pemkab : pemkab
# Polres : polres
# Rohul : rohul
# mendirikan : diri
# Tenda : tenda
# didirikan : diri
# upaya : upaya
# bantuan : bantu
# Hari : hari
# dirikan : diri
# Semua : semua
# membantu : bantu
# pengungsi : ungsi
# Afrizal : afrizal
# Seribu : ribu
# Suluk : suluk
# kaji : kaji
# Jumlah : jumlah
# 100200 : 100200
# Pasir : pasir
# Pangaraian : pangaraian
# Koto : koto
# Kaiti : kait
# 6090 : 6090
# sebagian : bagi
# kerabat : kerabat
# Babussalam : babussalam
# bertambah : tambah
# 280 : 280
# Halmahera : halmahera
# berpotensi : potensi
# tsunami : tsunami
# 52 : 52
# Maluku : malu
# 10 : 10
# Malut : malut
# berkedalaman : dalam
# Twitter : twitter
# 26122021 : 26122021
# 0922 : 0922
# Koordinat : koordinat
# Kedalaman : dalam
# Mag52 : mag52
# 26Des21 : 26des21
# 092253 : 092253
# Lok221 : lok221
# LU12679 : lu12679
# 130 : 130
# BaratLaut : baratlaut
# HALMAHERABARATMALUT : halmaherabaratmalut
# Kedlmn10 : kedlmn10
# Km : km
# tdk : tdk
# Luwu : luwu
# 32 : 32
# Sulsel : sulsel
# Sulawesi : sulawesi
# 2004 : 2004
# 8 : 8
# barat : barat
# aku : aku
# Twitternya : twitternya
# 254 : 254
# 12111 : 12111
# skala : skala
# Malili : malili
# Skala : skala
# Karangasem : karangasem
# Bali : bal
# 12 : 12
# 18122021 : 18122021
# 0656 : 0656
# 829 : 829
# 11562 : 11562
# 14 : 14
# berarti : arti
# Nias : nias
# IIIII : iiiii
# 43 : 43
# 17122021 : 17122021
# 2138 : 2138
# 106 : 106
# 9782 : 9782
# Gunungsitoli : gunungsitoli
# Sedangkan : sedang
# terasa : asa
# 34 : 34
# 1814 : 1814
# diterangkan : terang
# resmi : resmi
# Yogyakarta : yogyakarta
# 780 : 780
# 11247 : 11247
# Atau : atau
# Jatim : jatim
# dibaca : baca
# Gunung : gunung
# aktivitas : aktivitas
# Flores : flores
# Semeru : meru
# Supartoyo : supartoyo
# 2021 : 2021
# geologis : geologis
# Awu : awu
# status : status
# siaga : siaga
# Rentetan : rentet
# Kepulauan : pulau
# vulkanik : vulkanik
# Selayar : layar
# Kemudian : kemudian
# level : level
# berkaitan : kait
# kenaikan : naik
# normal : normal
# Merapi : rapi
# dekat : dekat
# sesar : sesar
# Geologi : geologi
# Erupsi : erupsi
# SemeruGempa : semerugempa
# berupa : upa
# kegempaan : gempa
# Di : di
# Lumajang : lumajang
# erupsi : erupsi
# Tak : tak
# berselang : selang
# Sangihe : sangihe
# seiring : iring
# meningkatnya : tingkat
# genap : genap
# minggu : minggu
# 74 : 74
# berdekatan : dekat
# muncul : muncul
# 50 : 50
# sama : sama
# Apakah : apakah
# semuanya : semua
# saling : saling
# PVMBG : pvmbg
# rentetan : rentet
# belakangan : belakang
# secara : cara
# memengaruhi : pengaruh
# halnya : hal
# Biasanya : biasa
# memicu : picu
# sifat : sifat
# berpengaruh : pengaruh
# pengaruhnya : pengaruh
# kekuatan : kuat
# kan : kan
# 51 : 51
# mudahmudahan : mudahmudahan
# mempengaruhi : pengaruh
# tingkat : tingkat
# aktivitasnya : aktivitas
# Kecuali : kecuali
# tujuh : tujuh
# ingat : ingat
# 2006 : 2006
# statusnya : status
# dipicu : picu
# 62 : 62
# pusatnya : pusat
# melanjutkan : lanjut
# hasil : hasil
# penelitian : teliti
# kaitannya : kait
# mekanismenya : mekanisme
# mendatar : datar
# ditimbulkan : timbul
# tersendiri : sendiri
# merusak : rusak
# luka : luka
# mengalami : alami
# jumlah : jumlah
# 2020 : 2020
# 25 : 25
# bangunan : bangun
# Dampak : dampak
# menelan : tel
# kedua : dua
# sebanyak : banyak
# Sepanjang : panjang
# Kali : kali
# Diguncang : guncang
# Gempa118 : gempa118
# Orang : orang
# Meninggal : tinggal
# Vulkanologi : vulkanologi
# mencatat : catat
# menimbulkan : timbul
# 118 : 118
# 6724 : 6724
# terbesar : besar
# terekam : rekam
# Mamuju : mamuju
# Januari : januari
# Dalam : dalam
# 105 : 105
# 6489 : 6489
# mengancam : ancam
# manusia : manusia
# meluluhlantakan : meluluhlantakan
# antaranya : antara
# gubernur : gubernur
# Sulbar : sulbar
# ambruk : ambruk
# diguncang : guncang
# retakan : reta
# likuifaksi : likuifaksi
# longsoran : longsor
# bagian : bagi
# April : april
# 9 : 9
# 121 : 121
# Blitar : blitar
# Trenggalek : trenggalek
# Tulungagung : tulungagung
# Kediri : diri
# Gresik : gresik
# berikutnya : ikut
# BangliKrasem : banglikrasem
# Tercatat : catat
# Dan : dan
# Tojo : tojo
# UnaUna : unauna
# Bila : bila
# dibandingkan : banding
# berjumlah : jumlah
# Dilihat : lihat
# rentang : rentang
# Kejadian : jadi
# terbanyak : banyak
# 2017 : 2017
# 19 : 19
# berfluktuasi : fluktuasi
# 525 : 525
# Mungkin : mungkin
# makin : makin
# Khofifah : khofifah
# pesisir : pesisir
# mitigasi : mitigasi
# rapat : rapat
# Gubernur : gubernur
# Indar : indar
# Parawansa : parawansa
# pantai : pantai
# Watuulo : watuulo
# Tinjau : tinjau
# Terdampak : dampak
# Ingatkan : ingat
# Pentingnya : penting
# Jalur : jalur
# Evakuasi : evakuasi
# kesempatan : sempat
# mengingatkan : ingat
# pentingnya : penting
# sewaktuwaktu : sewaktuwaktu
# Terutama : utama
# bermagnitudo : magnitudo
# Dusun : dusun
# Sumberejo : sumberejo
# Ambulu : ambulu
# membahas : bahas
# Pemkab : pemkab
# kunjungannya : kunjung
# menggelar : gelar
# paparan : papar
# Pendapa : pendapa
# Wahyawibawagraha : wahyawibawagraha
# 1612 : 1612
# mewakili : wakil
# Pemprov : pemprov
# mengajak : ajak
# evaluasi : evaluasi
# Yang : yang
# meskipun : meski
# dinilai : nilai
# dasarnya : dasar
# tentang : tentang
# hal : hal
# serius : serius
# Itu : itu
# provinsi : provinsi
# dikonfirmasi : konfirmasi
# usai : usai
# Provinsi : provinsi
# patahan : patah
# ring : ring
# of : of
# fire : fire
# rentan : rentan
# Patahan : patah
# peta : peta
# selatan : selatan
# Pulau : pulau
# Sehingga : sehingga
# terkonfirmasi : konfirmasi
# Terlebih : lebih
# early : early
# warning : warning
# jauh : jauh
# disampaikam : disampaikam
# Soal : soal
# Megathrust : megathrust
# semisal : misal
# nanti : nanti
# 29 : 29
# Maka : maka
# kirakira : kirakira
# menit : menit
# diri : diri
# mitigas : mitigas
# soal : soal
# ramburambu : ramburambu
# penyelamatan : selamat
# rawan : rawan
# Lempeng : lempeng
# dasar : dasar
# 1896 : 1896
# 1967 : 1967
# VIIIIX : viiiix
# berat : berat
# 38 : 38
# Beberkan : kan
# Fakta : fakta
# Rawan : rawan
# membeberkan : beber
# fakta : fakta
# kiranya : kira
# bahwa : bahwa
# Bidang : bidang
# 19122021 : 19122021
# membuat : buat
# sumber : sumber
# potensial : potensial
# subduksi : subduksi
# IndoAustralia : indoaustralia
# Subduksi : subduksi
# menghunjam : hunjam
# bawah : bawah
# Eurasia : eurasia
# zona : zona
# megathrust : megathrust
# sumbersumber : sumbersumber
# Baik : baik
# daratan : darat
# maupun : maupun
# sejarah : sejarah
# periode : periode
# dirangkum : rangkum
# LumajangJember : lumajangjember
# VI : vi
# ringansedang : ringansedang
# Juli : juli
# 2013 : 2013
# 59 : 59
# November : november
# 2016 : 2016
# 2018 : 2018
# 61 : 61
# fasilitas : fasilitas
# 6 : 6
# ternyata : nyata
# episenter : episenter
# kualitas : kualitas
# tahan : tahan
# buruk : buruk
# ramah : ramah
# tembok : tembok
# membunuh : bunuh
# melukai : luka
# Sebut : sebut
# Alarm : alarm
# Bangunan : bangun
# Asal : asal
# Bangun : bangun
# Secara : cara
# rinci : rinci
# 11 : 11
# alarm : alarm
# bagaimana : bagaimana
# Banyaknya : banyak
# menunjukkan : tunjuk
# struktural : struktural
# berjalan : jalan
# baik : baik
# perlu : perlu
# penilaian : nilai
# mampu : mampu
# membangun : bangun
# memaparkan : papar
# alternatifnya : alternatif
# Sebagai : bagai
# alternatif : alternatif
# bangunlah : bangun
# berbahan : bahan
# terbuat : buat
# kayu : kayu
# bambu : bambu
# didesain : desain
# menarik : tarik
# asal : asal
# bangun : bangun
# besi : besi
# tulangan : tulang
# membahayakan : bahaya
# penghuninya : hun
# menegaskan : tegas
# kebanyakan : banyak
# terluka : luka
# reruntuhan : runtuh
# utama : utama
# merealisasi : realisasi
# Nagan : nagan
# Raya : raya
# Aceh : aceh
# 49 : 49
# 2134 : 2134
# 459 : 459
# lintang : lintang
# utara : utara
# 9640 : 9640
# bujur : bujur
# jarak : jarak
# Takengon : takengon
# Heru : heru
# Rusak : rusak
# Mulai : mulai
# Ponpes : ponpes
# belasan : bas
# Rinciannya : rinciannya
# pondok : pondok
# pesantren : pesantren
# Sisanya : sisa
# tersebar : sebar
# Antara : antara
# Tempurejo : tempurejo
# Puger : puger
# Wuluhan : wuluhan
# Silo : silo
# Mudahmudahan : mudahmudahan
# berhatihati : berhatihati
# mendekat : dekat
# Misalnya : misal
# retak : retak
# tandasnya : tandas
# jangan : jangan
# mudah : mudah
# percaya : percaya
# jelas : jelas
# sumbernya : sumber
# Penta : penta
# Ketiga : tiga
# 30 : 30
# kaki : kaki
# Terluka : luka
# lukaluka : lukaluka
# Mereka : mereka
# Logistik : logistik
# Satria : satria
# 16122021 : 16122021
# mendapat : dapat
# medis : medis
# mereka : mereka
# membaik : baik
# tertangani : tangan
# Siti : siti
# Lutfia : lutfia
# Tari : tari
# 70 : 70
# Endang : endang
# Sulistyowati : sulistyowati
# dada : dada
# punggung : punggung
# Watu : watu
# Ulo : ulo
# rincian : rincian
# 23 : 23
# atap : atap
# Balai : balai
# Wonoasri : wonoasri
# tambah : tambah
# demikian : demikian
# pengumpulan : kumpul
# final : final
# pendataan : data
# Sigit : sigit
# Update : update
# 46 : 46
# Rusak6 : rusak6
# Luka : luka
# Sukorambi : sukorambi
# update : update
# Hasil : hasil
# asesmen : asesmen
# relawan : rawan
# dibantu : bantu
# perangkat : perangkat
# Akbari : akbar
# ataupun : atau
# 33 : 33
# musibah : musibah
# menambahkan : tambah
# tdak : tdak
# kejatuhan : jatuh
# kakinya : kaki
# terkilir : kilir
# total : total
# Para : para
# korbankorban : korbankorban
# mendapatkan : dapat
# puskesmas : puskesmas
# fasum : fasum
# sekolah : sekolah
# balai : balai
# pungkas : pungkas
# Bambang : bambang
# Banyuwangi : banyuwangi
# Setiyo : setiyo
# Prayitno : prayitno
# kaget : kaget
# lari : lari
# keluar : keluar
# seakan : akan
# Mutakhirkan : mutakhir
# dikagetkan : kaget
# dihimpun : himpun
# 855 : 855
# 11348 : 11348
# tepatnya : tepat
# parameter : parameter
# M50 : m50
# diterima : terima
# Surabaya : surabaya
# Aktivitas : aktivitas
# terhenti : henti
# mengaku : aku
# kerasa : rasa
# Dana : dana
# Pengantigan : pengantigan
# penduduk : duduk
# terbangun : bangun
# IV : iv
# bila : bila
# Denpasar : denpasar
# Kuta : kuta
# Legian : legi
# Jimbaran : jimbaran
# Karangkates : karangkates
# Bondowoso : bondowoso
# papar : papar
# Sesar : sesar
# Selasa : selasa
# 1412 : 1412
# mekanisme : mekanisme
# NTT : ntt
# geser : geser
# sedangkan : sedang
# sensitivitas : sensitivitas
# kuat : kuat
# terpetakan : peta
# selama : lama
# menonjol : tonjol
# klaster : klaster
# 663 : 663
# Ungkap : ungkap
# Aktif : aktif
# Pernah : pernah
# Teridentifikasi : identifikasi
# membangkitkan : bangkit
# teridentifikasi : identifikasi
# mengidentifikasi : identifikasi
# memetakan : meta
# melihat : lihat
# pembangkit : bangkit
# dicirikan : ciri
# Tampak : tampak
# tanggal : tanggal
# Artinya : arti
# sesarnya : sesar
# turut : turut
# perhatian : perhati
# kegempaannya : gempa
# rendah : rendah
# 2009 : 2009
# umurnya : umur
# mengungkapkan : ungkap
# dikategorikan : kategori
# tipe : tipe
# sini : sini
# tampak : tampak
# mengklaster : mengklaster
# relatif : relatif
# Sunda : sunda
# Kecil : kecil
# NTB : ntb
# 19800an : 19800an
# setidaknya : tidak
# ratarata : ratarata
# hitung : hitung
# frekuensinya : frekuensi
# Nusa : nusa
# Tenggara : tenggara
# 143 : 143
# panik : panik
# wajar : wajar
# 17 : 17
# 1600 : 1600
# Wita : wita
# 265 : 265
# Rabu : rabu
# 1512 : 1512
# 230 : 230
# 145 : 145
# 1712 : 1712
# Catatan : catat
# 68 : 68
# terkecil : kecil
# Melansir : lansir
# Mana : mana
# Saja : saja
# dirilis : rilis
# Meskipun : meski
# diimbau : imbau
# diinformasikan : informasi
# 0601 : 0601
# ucap : ucap
# terkejut : kejut
# berlarian : lari
# kuatnya : kuat
# memperhatikan : perhati
# hiposenternya : hiposenternya
# intraplate : intraplate
# earthquake : earthquake
# situs : situs
# merasakan : rasa
# Diketahui : tahu
# Mag51 : mag51
# 16Des21 : 16des21
# 060133 : 060133
# Lok855 : lok855
# LS11349 : ls11349
# 42 : 42
# BaratDaya : baratdaya
# JEMBERJATIM : jemberjatim
# Cianjur : cianjur
# gemp : gemp
# aitu : aitu
# 0741 : 0741
# 699 : 699
# 10716 : 10716
# berpusat : pusat
# arat : arat
# Cibeber : cibeber
# Hendro : hendro
# dangkal : dangkal
# lokal : lokal
# Penyebabnya : sebab
# BBMKG : bbmkg
# Tangerang : tangerang
# Nugroho : nugroho
# Dampaknya : dampak
# 0803 : 0803
# monitoring : monitoring
# merekomendasikan : rekomendasi
# tenang : tenang
# terpengaruh : pengaruh
# isu : isu
# dipertanggungjawabkan : dipertanggungjawabkan
# kebenarannya : benar
# Pastikan : pasti
# bersumber : sumber
# disebarkan : sebar
# kanal : kanal
# komunikasi : komunikasi
# terverifikasi : verifikasi
# MBD : mbd
# 56 : 56
# Ilih : ilih
# Damer : damer
# Bebar : bebar
# Kehli : kehli
# Rumah1 : rumah1
# Tempat : tempat
# Ibadah : ibadah
# Nasional : nasional
# Penanggulangan : tanggulang
# detik : detik
# berhamburan : hambur
# keras : keras
# durasi : durasi
# Plt : plt
# tertulis : tulis
# berdampak : dampak
# pengungsian : ungsi
# ibadah : ibadah
# 163 : 163
# 217 : 217
# 385 : 385
# Kedua : dua
# Banda : banda
# kajian : kaji
# inaRISK : inarisk
# bahaya : bahaya
# kategori : kategori
# Diberitakan : berita
# 1126 : 1126
# 1803 : 1803
# Seluma : seluma
# Bengkulu : bengkulu
# 2109 : 2109
# 457 : 457
# 10209 : 10209
# 77 : 77
# daya : daya
# Arga : arga
# Makmur : makmur
# Pagi : pagi
# Rusak3 : rusak3
# Getaran : getar
# 55 : 55
# Bolaang : bolaang
# Mongondow : mongondow
# Sulut : sulut
# 2201 : 2201
# 006 : 006
# 12349 : 12349
# 73 : 73
# 90 : 90
# Kotamobagu : kotamobagu
# Gorontalo : gorontalo
# Luwuk : luwuk
# Poso : poso
# Sikka : sikka
# Pasimarannu : pasimarannu
# Pasilambena : pasilambena
# 1700 : 1700
# 200 : 200
# jabatan : jabat
# mengantisipasi : antisipasi
# 4838 : 4838
# Selayar226 : selayar226
# Masih : masih
# Mengungsi : ungsi
# perkembangan : kembang
# berasal : asal
# Sebaran : sebar
# Mintuu : mintuu
# penyintas : sintas
# 2200 : 2200
# Lambego : lambego
# 900 : 900
# Lakawu : lakawu
# 500 : 500
# Puncak : puncak
# Majapahit : majapahit
# 250 : 250
# Lamantu : lamantu
# Langundi : langundi
# Lembangmatene : lembangmatene
# Latokdo : latokdo
# Timjur : timjur
# 192 : 192
# Kalaotoa : kalaotoa
# 300 : 300
# Barumbung : barumbung
# memakan : makan
# 96 : 96
# 825 : 825
# 502 : 502
# pelabuhan : labuh
# rakyat : rakyat
# kades : kades
# gudang : gudang
# samping : samping
# pertemuan : temu
# Petugas : tugas
# mendata : data
# keenam : enam
# Pengendalian : kendali
# Operasi : operasi
# 226 : 226
# aula : aula
# Manggarai : manggarai
# berpesan : pesan
# bersiaga : siaga
# mengecek : ecek
# 547 : 547
# menghimbau : menghimbau
# pascagempa : pascagempa
# beraktivitas : aktivitas
# kamar : kamar
# mandi : mandi
# Rosyid : rosyid
# plafon : plafon
# anggota : anggota
# selamat : selamat
# Remaja : remaja
# Terjebak : jebak
# Kamar : kamar
# Mandi : mandi
# remaja : remaja
# perempuan : perempuan
# terjebak : jebak
# Anak : anak
# tua : tua
# Pria : pria
# menceritakan : cerita
# sebelum : belum
# putrinya : putri
# buang : buang
# hebat : hebat
# nomor : nomor
# Nggak : nggak
# Akibatnya : akibat
# tubuh : tubuh
# tertimpa : timpa
# Perempuan : perempuan
# Langsung : langsung
# Plafon : plafon
# runtuh : runtuh
# Termasuk : masuk
# lokasinya : lokasi
# ruang : ruang
# Kendati : kendati
# pria : pria
# bersyukur : syukur
# Mengingat : ingat
# dirasa : rasa
# berjatuhan : jatuh
# Bersyukur : syukur
# Pandas Apply: 100%|██████████| 39/39 [00:00<00:00, 18217.83it/s]
