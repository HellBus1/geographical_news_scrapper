# %% [markdown]
# # Data Preparation

# %%
# import necessary libraries to get the data
from nltk.tokenize import sent_tokenize
import pandas as pd
import string

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# in case we need to download NLTK punctuations
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#@title Dataset load for model create
# dataset = pd.read_csv("/content/drive/MyDrive/NER_v2.2/dataset_ner/df_total.csv")
dataset = pd.read_csv("/content/drive/MyDrive/NER_Final/dataset_ner/df_train_ner.csv")
dataset.head()
# Out:
#                                                title  \
# 0  Visual Interaktif: Drama Asmara Pembunuh Eneng...
# 1  262 Pelaku Curas, Curat, dan Curanmor di Jatim...
# 2  Terungkap! Ini Identitas Terduga Maling Motor ...
# 3  Pencuri Motor yang Dikejar di Suramadu hingga ...
# 4  Terduga Maling Motor yang Tewas Dibakar di Ban...
#
#                             date  \
# 0  Jumat, 20 Mei  2022 13:19 WIB
# 1    Rabu, 10 Nov 2021 18:11 WIB
# 2    Rabu, 06 Okt 2021 19:42 WIB
# 3   Kamis, 21 Okt 2021 22:11 WIB
# 4    Rabu, 06 Okt 2021 20:09 WIB
#
#                                          description                      nama
# 0  alias aden membunuh eneng kulsum wanita cibada...             aden, maryono
# 1  262 tersangka diamankan masingmasing berbeda c...  slamet, hadi, supraptoyo
# 2  terungkap inisial 50 warga desa parseh kecamat...     sigit nursiyo dwiyugo
# 3  pas tangkap ngakunya mencuri beli motor mencur...                     mahur
# 4  polres bangkalan proses kasusnya curanmor tera...     sigit nursiyo dwiyugo

# %%
#@title Flatten dataframe
dataset_list = []

for i in range(0, dataset.shape[0]):
  dataset_list.append(dataset.iloc[i, 2])

print({
      'Data': len(dataset_list)
})
# Out:
# {'Data': 104}

# %%
dataset_list

# %%
#@title Join array with space
text_ready = ' '.join(dataset_list[0:104])
# text_ready = ' '.join(dataset_list)
text_ready
# Out:
# 'alias aden membunuh eneng kulsum wanita cibadak kabupaten sukabumi pria diduga merencanakan aksi kejinya jumat 135 malam aden sengaja membawa sebilah pisau menunggu eneng kulsum rumahnya pelaku menyerang menusuk korban nyawa eneng tertolong polisi memburu menangkap aden motifnya keterangan saksi keterangan tersangka dendam korban menjalin hubungan tersangka korban rujuk mantan suaminya kapolsek cibadak kompol maryono 262 tersangka diamankan masingmasing berbeda curat 127 tersangka curas 51 tersangka curanmor 84 tersangka terang wakapolda jatim brigjen slamet hadi supraptoyo jumpa pers gedung mahameru rabu 10112021 curat menyoroti curas aksinya bandit kerap korbannya terluka sengaja dilukai curas tersangka menjambret tas milik korban mengendarai sepeda motor menodongkan senjata tajam tersangka segan segan melukai korbannya perlawanan hadi curat modus aksinya tersangka merusak pintu jendela rumah gudang milik korban imbuhnya kesempatan polda jatim menyerahkan unit kendaraan roda unit sepeda motor pemiliknya korban curanmor salah korban hasanuddin mengaku bersyukur terimakasih polisi kendaraanya ucapkan terima kasih kapolda anggota jatanras menangkap pelaku mencuri mobil hasanuddin menceritakan mobilnya hilang sebulan keterangan polisi mobilnya ditemukan exit tol japanan mobil parkir rumah 1700 wib 0300 wib keterangannya mobil ditemukan tol japanan warga pandaan pasuruan iwdiwd terungkap inisial 50 warga desa parseh kecamatan socah beber kasat reskrim polres bangkalan akp sigit nursiyo dwiyugo rabu 6102021 sigit terungkapnya identitas korban petugas handphone perangkat desa handphone ditemukan lokasi korban dibakar temuan polisi menyelidikinya handphone milik korban dibakar petugas mengamankan handphone perangkat desa nemuin korban dibakar kroscek registrasi nomornya pas kknya papar sigit sigit identitasnya terungkap menghubungi keluarganya jenazah diserahkan malam kemarin dikuburkan malam identitasnya hubungi keluarganya sigit terduga maling motor curanmor tewas dibakar massa peristiwa desa rabesen kecamatan kwanyar bangkalan madura kapolsek kwanyar iptu mansur dikonfirmasi membenarkan kejadian mansur peristiwa 0200 wib kejadiannya 0200 wib massa pelaku dibakar motornya mansur 5102021 iwdiwd pas tangkap ngakunya mencuri beli motor mencuri pemilik motor mahur kamis 21102021 mahur percaya menangkap memborgolnya tiang listrik polisi polsek sukolilo bangkalan percaya borgol milik sekuriti proyek nunggu polisi sukolilo kantor polisi ngaku membeli mahur beli hasil uangnya pakai sabu percaya omongnya ngelantur mahur mahur menangkap menyerahkan pencuri motor polisi motornya dicuri diambil kantor polisi pengembangan mencari pelaku tkp laporan terang mahur mahur pencurian motornya order mengambil makanan jalan embong malang mengambil order tahutahu honda beat bernomor pelat 6432 li miliknya hilang motor dikunci ganda order motor parkir ambil order tahutahu motor hilang kunci mahur motor hilang mahur melaporkannya polsek genteng saudaranya berinisiatif menunggu pencuri jembatan suramadu ditunggu jam motornya pelaku melintas jembatan suramadu kehilangan momen mahur keempat saudaranya menunggangi motornya masingmasing mengejar pelaku polres bangkalan proses kasusnya curanmor terang kasat reskrim polres bangkalan akp sigit nursiyo dwiyugo rabu 6102021 sigit motor dibakar motor hasil kejahatan motor korban motornya nama hasil nyuri pas kejadian beber sigit sigit menyelidiki massa terlibat membakar korban namanama terlibat dikantongi dicari mempertanggungjawabkan perbuatannya selidiki cari mempertanggungjawabkan pencurian menghilangkan nyawa salah dipanggil dalami mengumpulkan keterangan saksisaksi sigit terduga maling motor curanmor tewas dibakar massa peristiwa desa rabesen kecamatan kwanyar bangkalan madura kapolsek kwanyar iptu mansur dikonfirmasi membenarkan kejadian mansur peristiwa 0200 wib kejadiannya 0200 wib massa pelaku dibakar motornya mansur 5102021 video maling sepeda beraksi perumahan elite garut iwdiwd pembunuhan manukan tama k ...

# %% [markdown]
# # Labelling

# %%
annotations = sorted(['nama'])
annotations
# Out:
# ['nama']

# %%
# install Sastrawi
# !pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 7.8 MB/s
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
#@title Import
from nltk.tokenize import word_tokenize
import itertools
import re
import numpy as np
import string
from tqdm import tqdm

# %%
#@title convert_to_spaCyformat
def convert_to_spaCyformat(df, listOfEntities):
    """
    This function is used to convert the BIO-tagged-DF to spaCy format annotations.
    
    Args:
    - df (pandas.DataFrame) > BIO-tagged dataframe consisting of two columns, i.e. token and BIO_tag
    - listOfEntities (list) > list of entities/annotations used
    
    Return:
    - [text, enti] > a list consisting of the text (combined from the tokens) and the interested entities as accordance with spaCy format
    """
    # check if NaN exists
    assert not (df.iloc[:,0].isnull().any() or df.iloc[:,1].isnull().any()), 'The dataset contains nan value.'
    
    # create a dictionary to save the columns of 'token' and 'BIO_tag', and we also define the index of tokens in order
    dictTemp = {}
    dictTemp['token'] = np.array(df.iloc[:,0])
    dictTemp['BIO_tag'] = np.array(df.iloc[:,1].str.lower())
    dictTemp['indices'] = np.array([len(i) for i in dictTemp['token']])

    # first, we need to get the index of the first token
    total_idx = [dictTemp['indices'][0]] 
    temp = dictTemp['indices'][0]
    
    # then we use for loop to count index for each token in cumulative
    for i in range(len(dictTemp['indices'])):
        if i > 0:
            temp += dictTemp['indices'][i]
            total_idx.append(temp)

    # create variable for the start index of each token
    dictTemp['start_idx'] = np.array([total_idx[i-1] if i > 0 else 0 for i in range(len(total_idx))])

    # create variable for the last index of each token
    dictTemp['end_idx'] = np.array(total_idx)
    del dictTemp['indices'] # we no longer need variable indices. then remove it.

    enti = {}
    entities = []
    text = ''.join(dictTemp['token'])
    
    # combine each of listOfEntities with prefix 'b-', 'i-', and 'e-', and add 'o' annotation
    listOfEntities = ['b-'+i.lower() for i in listOfEntities] + \
                     ['i-'+i.lower() for i in listOfEntities] + \
                     ['e-'+i.lower() for i in listOfEntities] + ['o']
    
    # check if each BIO-tag is in listOfEntities
    error_tag = []
    error_boolean = []
    for i in np.unique(dictTemp['BIO_tag']):
        if i in listOfEntities:
            error_boolean.append(True)
        else:
            error_boolean.append(False)
            error_tag.append(i)
    assert all(error_boolean), "Some BIO-tag not listed in listOfEntities arg. {}".format(error_tag)
    
    # fill in entities list with all non 'O' annotations
    for row in range(len(dictTemp['token'])):
        if dictTemp['BIO_tag'][row] != 'o':
            entities.append((dictTemp['start_idx'][row], 
                             dictTemp['end_idx'][row], 
                             dictTemp['BIO_tag'][row]))

    
    start = []
    end = []
    BIO = []
    i = 0
    while i < len(entities):
        try:
            if entities[i][2][2:] == entities[i+1][2][2:]:
                if entities[i][2][0] == 'b':
#                     print('start1', entities[i][0])
                    start.append(entities[i][0])
                    i += 1
                    if entities[i][2][0] == 'e':
#                         print('end1a', entities[i][1])
                        end.append(entities[i][1])
                        BIO.append(entities[i][2][2:])
                        i += 1
                        continue
                    elif entities[i][2][0] == 'i':
                        for j in range(i, len(entities)):
                            if entities[j][2][0] != 'e' and j < len(entities)-1:
#                                 print('sana', entities[j])
                                continue
                            elif entities[j][2][0] == 'e':
#                                 print('end1b', entities[j][1])
                                end.append(entities[j][1])
                                BIO.append(entities[j][2][2:])
                                i = j+1
                                break
                            else:
                                assert 1 == 0, \
                                    "Something error in the BIO-tag you wrote. Error BIO tag: '{}'" \
                                    .format(entities[j][2])
                    elif entities[i][2][0] == 'b':
#                         print('end1b', entities[i-1][1])
                        end.append(entities[i-1][1])
                        BIO.append(entities[i-1][2][2:])
                        continue
                        
#                         print('ss',i,j)
            else:
#                 print('start2a', entities[i][0], i)
                start.append(entities[i][0])
#                 print('end2a', entities[i][1], i)
                end.append(entities[i][1])
                BIO.append(entities[i][2][2:])
                i += 1
        except IndexError:
#             print('start2b', entities[i][0], i)
            start.append(entities[i][0])
#             print('end2b', entities[i][1], i)
            end.append(entities[i][1])
            BIO.append(entities[i][2][2:])
            i += 1

    enti['entities'] = [(i,j,k) for i,j,k in zip(start, end, BIO)]
    return [text, enti]

# %%
#@title text_to_tagReadyDF
def text_to_tagReadyDF(input, isCSV=True, more_stopwords=None):
	"""
	This function is used to convert raw text of PUU (either CSV file or pandas Series) into tag-ready dataframe.

	Args:
	- input (pd.Series variable): either CSV file (enter its file location) or pandas Series. If you want to use pandas Series, set 'isCSV' arg to False.
	- isCSV (Boolean): if True, CSV input used. If False, pd.Series input used.
	- more_stopwords (list): add more stopwords if you'd like.

	Return:
	- result dataframe
	"""
    # in case Sastrawi not detected
	try:
		from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
		stopwords = StopWordRemoverFactory().get_stop_words()
	except ModuleNotFoundError:
		print("No module named 'Sastrawi' in your machine. Bypassing 'Sastrawi' dependency, but the number of stopwords will decrease.")
		stopwords = []

	# check input
	if isCSV:
		# add csv file that contains raw PUU texts
		text = pd.read_csv(input, delimiter='|')
		if text.iloc[:,0].dtype == 'O':
			text = text.iloc[:,0]
		else:
			raise ValueError("As 'isCSV' set to True, the 1st column of your CSV file should be the texts you'd like to process.")
			
	else:
		# if pd.Series expected
		if isinstance(input, pd.Series):		# check if data type is suitable
			text = input
		else:
			raise TypeError("As 'isCSV' set to False, 'input' should be a pandas Series.")

	# define punctuation
	punctAndSpace = string.punctuation + ' '
	# kita memerlukan karakter '(', ')', dan '.',
	# karena karakter tsb muncul di ayat dan angka
	punctAndSpace = punctAndSpace.replace('(','')
	punctAndSpace = punctAndSpace.replace(')','')
	punctAndSpace = punctAndSpace.replace('.','')

	# tambah stopwords dari argument variable
	if more_stopwords != None:	
		assert isinstance(more_stopwords, list), "'more_stopwords' arg should be list type."
		stopwords += more_stopwords

	stopwords = sorted(set(stopwords))

	# ubah Raw teks PUU menjadi tokens ke sebuah kolom df
	# lalu beri tagging 'O' secara otomatis pada tokens yang tidak masuk interest annotations
	dfList = []
	for idx, t in tqdm(enumerate(text)):
	    # tokenization
		tokens = [[word_tokenize(w), ','] for w in t.split()]
		print(tokens)
		tokens = list(itertools.chain(*list(itertools.chain(*tokens))))
		tokens = tokens[:-1]

		split_res = []
		for t in tokens:
			# if-else di bawah ini untuk mengcover token berbentuk seperti ini,
			# 'Jakarta-Bogor-Ciawi'
			if re.match(r'\w+\-\w+.*', t):
				line = t.split('-')
				for i,j in enumerate(line):
					split_res.append(j)
					if i < len(line)-1:
						split_res.append('-')
			else:
				split_res.append(t)
	    
	    # membuat tagging 'O' untuk token yang kita anggap tidak masuk list annotations
		# blank = ['' if i.lower() not in list(punctAndSpace) + stopwords else 'O' for i in split_res]
		blank = []
		for i in split_res:
			if i.lower() not in list(punctAndSpace) + stopwords:
				if i in dataset_list:
					blank.append('b-lokasi')
				else:
					blank.append('')
			else: 
				blank.append('O')
		 
		# buat menjadi df
		dfTemp = pd.DataFrame([split_res, blank]).T
		# beri nama kolom sesuai dengan index looping
		dfTemp.columns = ['token_' + str(idx),'BIO_tag_' + str(idx)]
		dfList.append(dfTemp)

	# concat semua df
	df = pd.concat(dfList, axis=1)

	# # save ke file csv yang siap ditag manual
	# df.to_csv(output_loc)
	# print('CSV output file successfully written.')

	return df

# %%
# print('barat' in dataset_list)
# print(dataset_list.index('barat'))
# print(dataset_list[2075])
tagready_df = text_to_tagReadyDF(pd.Series([text_ready]), isCSV=False)
# Out:
# 0it [00:00, ?it/s]
# [[['alias'], ','], [['aden'], ','], [['membunuh'], ','], [['eneng'], ','], [['kulsum'], ','], [['wanita'], ','], [['cibadak'], ','], [['kabupaten'], ','], [['sukabumi'], ','], [['pria'], ','], [['diduga'], ','], [['merencanakan'], ','], [['aksi'], ','], [['kejinya'], ','], [['jumat'], ','], [['135'], ','], [['malam'], ','], [['aden'], ','], [['sengaja'], ','], [['membawa'], ','], [['sebilah'], ','], [['pisau'], ','], [['menunggu'], ','], [['eneng'], ','], [['kulsum'], ','], [['rumahnya'], ','], [['pelaku'], ','], [['menyerang'], ','], [['menusuk'], ','], [['korban'], ','], [['nyawa'], ','], [['eneng'], ','], [['tertolong'], ','], [['polisi'], ','], [['memburu'], ','], [['menangkap'], ','], [['aden'], ','], [['motifnya'], ','], [['keterangan'], ','], [['saksi'], ','], [['keterangan'], ','], [['tersangka'], ','], [['dendam'], ','], [['korban'], ','], [['menjalin'], ','], [['hubungan'], ','], [['tersangka'], ','], [['korban'], ','], [['rujuk'], ','], [['mantan'], ','], [['suaminya'], ','], [['kapolsek'], ','], [['cibadak'], ','], [['kompol'], ','], [['maryono'], ','], [['262'], ','], [['tersangka'], ','], [['diamankan'], ','], [['masingmasing'], ','], [['berbeda'], ','], [['curat'], ','], [['127'], ','], [['tersangka'], ','], [['curas'], ','], [['51'], ','], [['tersangka'], ','], [['curanmor'], ','], [['84'], ','], [['tersangka'], ','], [['terang'], ','], [['wakapolda'], ','], [['jatim'], ','], [['brigjen'], ','], [['slamet'], ','], [['hadi'], ','], [['supraptoyo'], ','], [['jumpa'], ','], [['pers'], ','], [['gedung'], ','], [['mahameru'], ','], [['rabu'], ','], [['10112021'], ','], [['curat'], ','], [['menyoroti'], ','], [['curas'], ','], [['aksinya'], ','], [['bandit'], ','], [['kerap'], ','], [['korbannya'], ','], [['terluka'], ','], [['sengaja'], ','], [['dilukai'], ','], [['curas'], ','], [['tersangka'], ','], [['menjambret'], ','], [['tas'], ','], [['milik'], ','], [['korban'], ','], [['mengendarai'], ','], [['sepeda'], ','], [['motor'], ','], [['menodongkan'], ','], [['senjata'], ','], [['tajam'], ','], [['tersangka'], ','], [['segan'], ','], [['segan'], ','], [['melukai'], ','], [['korbannya'], ','], [['perlawanan'], ','], [['hadi'], ','], [['curat'], ','], [['modus'], ','], [['aksinya'], ','], [['tersangka'], ','], [['merusak'], ','], [['pintu'], ','], [['jendela'], ','], [['rumah'], ','], [['gudang'], ','], [['milik'], ','], [['korban'], ','], [['imbuhnya'], ','], [['kesempatan'], ','], [['polda'], ','], [['jatim'], ','], [['menyerahkan'], ','], [['unit'], ','], [['kendaraan'], ','], [['roda'], ','], [['unit'], ','], [['sepeda'], ','], [['motor'], ','], [['pemiliknya'], ','], [['korban'], ','], [['curanmor'], ','], [['salah'], ','], [['korban'], ','], [['hasanuddin'], ','], [['mengaku'], ','], [['bersyukur'], ','], [['terimakasih'], ','], [['polisi'], ','], [['kendaraanya'], ','], [['ucapkan'], ','], [['terima'], ','], [['kasih'], ','], [['kapolda'], ','], [['anggota'], ','], [['jatanras'], ','], [['menangkap'], ','], [['pelaku'], ','], [['mencuri'], ','], [['mobil'], ','], [['hasanuddin'], ','], [['menceritakan'], ','], [['mobilnya'], ','], [['hilang'], ','], [['sebulan'], ','], [['keterangan'], ','], [['polisi'], ','], [['mobilnya'], ','], [['ditemukan'], ','], [['exit'], ','], [['tol'], ','], [['japanan'], ','], [['mobil'], ','], [['parkir'], ','], [['rumah'], ','], [['1700'], ','], [['wib'], ','], [['0300'], ','], [['wib'], ','], [['keterangannya'], ','], [['mobil'], ','], [['ditemukan'], ','], [['tol'], ','], [['japanan'], ','], [['warga'], ','], [['pandaan'], ','], [['pasuruan'], ','], [['iwdiwd'], ','], [['terungkap'], ','], [['inisial'], ','], [['50'], ','], [['warga'], ','], [['desa'], ','], [['parseh'], ','], [['kecamatan'], ','], [['socah'], ','], [['beber'], ','], [['kasat'], ','], [['reskrim'], ','], [['polres'], ','], [['bangkalan'], ','], [['akp'], ','], [['sigit'], ','], [['nursiyo'], ','], [['dwiyugo'], ','], [['rabu'], ','], [['6102021'], ','], [['sigit'], ','], [['terungkapnya'], ','], [['identitas'], ...
# 1it [00:10, 10.30s/it]

# %%
print(tagready_df.shape)
tagready_df
# Out:
# (33965, 2)
#            token_0 BIO_tag_0
# 0            alias
# 1                ,         O
# 2             aden
# 3                ,         O
# 4         membunuh
# ...            ...       ...
# 33960   dipadamkan
# 33961            ,         O
# 33962  personelnya
# 33963            ,         O
# 33964   korsleting
#
# [33965 rows x 2 columns]

# %%
#@title Safe untagged dataset
link_for_save = "/content/drive/MyDrive/NER_Final/dataset_ner/file_to_tag/dataset_untagged10.csv"
tagready_df.to_csv(link_for_save, index=False)
tagready_df
# Out:
#            token_0 BIO_tag_0
# 0            alias
# 1                ,         O
# 2             aden
# 3                ,         O
# 4         membunuh
# ...            ...       ...
# 33960   dipadamkan
# 33961            ,         O
# 33962  personelnya
# 33963            ,         O
# 33964   korsleting
#
# [33965 rows x 2 columns]

# %% [markdown]
# hasil text_tagged.csv ku tagging manual di excel. b- (beginning), i- (inside), e- (end)

# %%
#@title Load Tagged Dataset
link_BIOtagged_file = "/content/drive/MyDrive/NER_Final/dataset_ner/file_to_tag/dataset_tagged10.csv"
df_tagged = pd.read_csv(link_BIOtagged_file)

# %%
# print(df_tagged.shape)
df_tagged = df_tagged.fillna('o')
# df_tagged = df_tagged.head(500)
df_tagged
# Out:
#            token_0 BIO_tag_0
# 0            alias         o
# 1                ,         O
# 2             aden    b-nama
# 3                ,         O
# 4         membunuh         o
# ...            ...       ...
# 33960   dipadamkan         o
# 33961            ,         O
# 33962  personelnya         o
# 33963            ,         O
# 33964   korsleting         o
#
# [33965 rows x 2 columns]

# %%
train_data = convert_to_spaCyformat(df_tagged, annotations)

# %%
train_data
# Out:
# ['alias,aden,membunuh,eneng,kulsum,wanita,cibadak,kabupaten,sukabumi,pria,diduga,merencanakan,aksi,kejinya,jumat,135,malam,aden,sengaja,membawa,sebilah,pisau,menunggu,eneng,kulsum,rumahnya,pelaku,menyerang,menusuk,korban,nyawa,eneng,tertolong,polisi,memburu,menangkap,aden,motifnya,keterangan,saksi,keterangan,tersangka,dendam,korban,menjalin,hubungan,tersangka,korban,rujuk,mantan,suaminya,kapolsek,cibadak,kompol,maryono,262,tersangka,diamankan,masingmasing,berbeda,curat,127,tersangka,curas,51,tersangka,curanmor,84,tersangka,terang,wakapolda,jatim,brigjen,slamet,hadi,supraptoyo,jumpa,pers,gedung,mahameru,rabu,10112021,curat,menyoroti,curas,aksinya,bandit,kerap,korbannya,terluka,sengaja,dilukai,curas,tersangka,menjambret,tas,milik,korban,mengendarai,sepeda,motor,menodongkan,senjata,tajam,tersangka,segan,segan,melukai,korbannya,perlawanan,hadi,curat,modus,aksinya,tersangka,merusak,pintu,jendela,rumah,gudang,milik,korban,imbuhnya,kesempatan,polda,jatim,menyerahkan,unit,kendaraan,roda,unit,sepeda,motor,pemiliknya,korban,curanmor,salah,korban,hasanuddin,mengaku,bersyukur,terimakasih,polisi,kendaraanya,ucapkan,terima,kasih,kapolda,anggota,jatanras,menangkap,pelaku,mencuri,mobil,hasanuddin,menceritakan,mobilnya,hilang,sebulan,keterangan,polisi,mobilnya,ditemukan,exit,tol,japanan,mobil,parkir,rumah,1700,wib,300,wib,keterangannya,mobil,ditemukan,tol,japanan,warga,pandaan,pasuruan,iwdiwd,terungkap,inisial,50,warga,desa,parseh,kecamatan,socah,beber,kasat,reskrim,polres,bangkalan,akp,sigit,nursiyo,dwiyugo,rabu,6102021,sigit,terungkapnya,identitas,korban,petugas,handphone,perangkat,desa,handphone,ditemukan,lokasi,korban,dibakar,temuan,polisi,menyelidikinya,handphone,milik,korban,dibakar,petugas,mengamankan,handphone,perangkat,desa,nemuin,korban,dibakar,kroscek,registrasi,nomornya,pas,kknya,papar,sigit,sigit,identitasnya,terungkap,menghubungi,keluarganya,jenazah,diserahkan,malam,kemarin,dikuburkan,malam,identitasnya,hubungi,keluarganya,sigit,terduga,maling,motor,curanmor,tewas,dibakar,massa,peristiwa,desa,rabesen,kecamatan,kwanyar,bangkalan,madura,kapolsek,kwanyar,iptu,mansur,dikonfirmasi,membenarkan,kejadian,mansur,peristiwa,200,wib,kejadiannya,200,wib,massa,pelaku,dibakar,motornya,mansur,5102021,iwdiwd,pas,tangkap,ngakunya,mencuri,beli,motor,mencuri,pemilik,motor,mahur,kamis,21102021,mahur,percaya,menangkap,memborgolnya,tiang,listrik,polisi,polsek,sukolilo,bangkalan,percaya,borgol,milik,sekuriti,proyek,nunggu,polisi,sukolilo,kantor,polisi,ngaku,membeli,mahur,beli,hasil,uangnya,pakai,sabu,percaya,omongnya,ngelantur,mahur,mahur,menangkap,menyerahkan,pencuri,motor,polisi,motornya,dicuri,diambil,kantor,polisi,pengembangan,mencari,pelaku,tkp,laporan,terang,mahur,mahur,pencurian,motornya,order,mengambil,makanan,jalan,embong,malang,mengambil,order,tahutahu,honda,beat,bernomor,pelat,6432,li,miliknya,hilang,motor,dikunci,ganda,order,motor,parkir,ambil,order,tahutahu,motor,hilang,kunci,mahur,motor,hilang,mahur,melaporkannya,polsek,genteng,saudaranya,berinisiatif,menunggu,pencuri,jembatan,suramadu,ditunggu,jam,motornya,pelaku,melintas,jembatan,suramadu,kehilangan,momen,mahur,keempat,saudaranya,menunggangi,motornya,masingmasing,mengejar,pelaku,polres,bangkalan,proses,kasusnya,curanmor,terang,kasat,reskrim,polres,bangkalan,akp,sigit,nursiyo,dwiyugo,rabu,6102021,sigit,motor,dibakar,motor,hasil,kejahatan,motor,korban,motornya,nama,hasil,nyuri,pas,kejadian,beber,sigit,sigit,menyelidiki,massa,terlibat,membakar,korban,namanama,terlibat,dikantongi,dicari,mempertanggungjawabkan,perbuatannya,selidiki,cari,mempertanggungjawabkan,pencurian,menghilangkan,nyawa,salah,dipanggil,dalami,mengumpulkan,keterangan,saksisaksi,sigit,terduga,maling,motor,curanmor,tewas,dibakar,massa,peristiwa,desa,rabesen,kecamatan,kwanyar,bangkalan,madura,kapolsek,kwanyar,iptu,mansur,dikonfirmasi,membenarkan,kejadian,mansur,peristiwa,200,wib,kejadiannya,200,wib,massa,pelaku,dibakar,motornya,mansur,5102021,video,maling,sepeda,beraksi,perumahan,elite,garut,iwdiwd,pembunuhan,manukan,tama,kecam ...
#  {'entities': [(6, 10, 'nama'),
#    (20, 25, 'nama'),
#    (121, 125, 'nama'),
#    (165, 170, 'nama'),
#    (225, 230, 'nama'),
#    (266, 270, 'nama'),
#    (413, 420, 'nama'),
#    (558, 564, 'nama'),
#    (565, 569, 'nama'),
#    (570, 580, 'nama'),
#    (845, 849, 'nama'),
#    (1050, 1060, 'nama'),
#    (1187, 1197, 'nama'),
#    (1493, 1514, 'nama'),
#    (1528, 1533, 'nama'),
#    (1810, 1815, 'nama'),
#    (1816, 1821, 'nama'),
#    (1952, 1957, 'nama'),
#    (2088, 2094, 'nama'),
#    (2129, 2135, 'nama'),
#    (2204, 2210, 'nama'),
#    (2288, 2293, 'nama'),
#    (2309, 2314, 'nama'),
#    (2481, 2486, 'nama'),
#    (2544, 2549, 'nama'),
#    (2550, 2555, 'nama'),
#    (2684, 2689, 'nama'),
#    (2690, 2695, 'nama'),
#    (2913, 2918, 'nama'),
#    (2932, 2937, 'nama'),
#    (3099, 3104, 'nama'),
#    (3258, 3279, 'nama'),
#    (3293, 3298, 'nama'),
#    (3393, 3398, 'nama'),
#    (3399, 3404, 'nama'),
#    (3645, 3650, 'nama'),
#    (3781, 3787, 'nama'),
#    (3822, 3828, 'nama'),
#    (3897, 3903, 'nama'),
#    (4101, 4107, 'nama'),
#    (4108, 4112, 'nama'),
#    (4113, 4120, 'nama'),
#    (4174, 4182, 'nama'),
#    (4242, 4248, 'nama'),
#    (4508, 4514, 'nama'),
#    (4515, 4521, 'nama'),
#    (4573, 4579, 'nama'),
#    (4762, 4768, 'nama'),
#    (4769, 4775, 'nama'),
#    (4936, 4942, 'nama'),
#    (5019, 5038, 'nama'),
#    (5054, 5059, 'nama'),
#    (5306, 5311, 'nama'),
#    (5850, 5866, 'nama'),
#    (6018, 6024, 'nama'),
#    (6102, 6108, 'nama'),
#    (6816, 6829, 'nama'),
#    (6878, 6884, 'nama'),
#    (6912, 6916, 'nama'),
#    (7011, 7016, 'nama'),
#    (7017, 7021, 'nama'),
#    (7022, 7029, 'nama'),
#    (7030, 7037, 'nama'),
#    (7041, 7048, 'nama'),
#    (7208, 7213, 'nama'),
#    (7253, 7258, 'nama'),
#    (7440, 7445, 'nama'),
#    (7869, 7887, 'nama'),
#    (8083, 8087, 'nama'),
#    (8088, 8093, 'nama'),
#    (8320, 8324, 'nama'),
#    (8325, 8330, 'nama'),
#    (8331, 8335, 'nama'),
#    (8450, 8454, 'nama'),
#    (8711, 8715, 'nama'),
#    (8716, 8720, 'nama'),
#    (8804, 8808, 'nama'),
#    (8809, 8816, 'nama'),
#    (8938, 8945, 'nama'),
#    (9357, 9364, 'nama'),
#    (9579, 9586, 'nama'),
#    (9935, 9942, 'nama'),
#    (9970, 9977, 'nama'),
#    (10086, 10093, 'nama'),
#    (10275, 10283, 'nama'),
#    (10445, 10453, 'nama'),
#    (10454, 10462, 'nama'),
#    (10468, 10475, 'nama'),
#    (10548, 10555, 'nama'),
#    (10689, 10697, 'nama'),
#    (10734, 10741, 'nama'),
#    (10823, 10829, 'nama'),
#    (10830, 10833, 'nama'),
#    (10834, 10844, 'nama'),
#    (10875, 10882, 'nama'),
#    (10956, 10962, 'nama'),
#    (10975, 10981, 'nama'),
#    (11000, 11007, 'nama'),
#    (11038, 11045, 'nama'),
#    (11139, 11145, 'nama'),
#    (11146, 11152, 'nama'),
#    (11187, 11194, 'nama'),
#    (11229, 11236, 'nama'),
#    (11460, 11467, 'nama'),
#    (11468, 11473, 'nama'),
#    (11474, 11480, 'nama'),
#    (11767, 11774, 'nama'),
#    (11951, 11958, 'nama'),
#    (12004, 12011, 'nama'),
#    (12176, 12183, 'nama'),
#    (12273, 12280, 'nama'),
#    (12366, 12373, 'nama'),
#    (14205, 14211, 'nama'),
#    (14399, 14405, 'nama'),
#    (14541, 14546, 'nama'),
#    (14699, 14705, 'nama'),
#    (14855, 14859, 'nama'),
#    (15363, 15368, 'nama'),
#    (15635, 15640, 'nama'),
#    (16055, 16060, 'nama'),
#    (16251, 16255, 'nama'),
#    (16405, 16409, 'nama'),
#    (16561, 16565, 'nama'),
#    (16935, 16939, 'nama'),
#    (17167, 17171, 'nama'),
#    (17172, 17184, 'nama'),
#    (17209, 17213, 'nama'),
#    (17482, 17486, 'nama'),
#    (17745, 17749, 'nama'),
#    (17923, 17929, 'nama'),
#    (18112, 18118, 'nama'),
#    (18242, 18248, 'nama'),
#    (18444, 18450, 'nama'),
#    (18933, 18939, 'nama'),
#    (19660, 19665, 'nama'),
#    (19672, 19678, 'nama'),
#    (19825, 19830, 'nama'),
#    (19831, 19837, 'nama'),
#    (20292, 20297, 'nama'),
#    (20298, 20307, 'nama'),
#    (20368, 20377, 'nama'),
#    (20549, 20558, 'nama'),
#    (20699, 20708, 'nama'),
#    (20753, 20762, 'nama'),
#    (20857, 20866, 'nama'),
#    (21977, 21983, 'nama'),
#    (22112, 22118, 'nama'),
#    (22833, 22838, 'nama'),
#    (23220, 23236, 'nama'),
#    (23671, 23675, 'nama'),
#    (23793, 23797, 'nama'),
#    (23902, 23906, 'nama'),
#    (24954, 24958, 'nama'),
#    (24959, 24964, 'nama'),
#    (25065, 25069, 'nama'),
#    (25070, 25075, 'nama'),
#    (25202, 25206, 'nama'),
#    (25207, 25212, 'nama'),
#    (25244, 25248, 'nama'),
#    (25249, 25254, 'nama'),
#    (25321, 25325, 'nama'),
#    (25326, 25331, 'nama'),
#    (25378, 25382, 'nama'),
#    (25383, 25388, 'nama'),
#    (25429, 25433, 'nama'),
#    (25434, 25439, 'nama'),
#    (25465, 25470, 'nama'),
#    (25471, 25478, 'nama'),
#    (25796, 25800, 'nama'),
#    (25907, 25911, 'nama'),
#    (26141, 26147, 'nama'),
#    (26228, 26233, 'nama'),
#    (26234, 26239, 'nama'),
#    (26280, 26285, 'nama'),
#    (26341, 26345, 'nama'),
#    (26409, 26414, 'nama'),
#    (26415, 26420, 'nama'),
#    (26592, 26597, 'nama'),
#    (26598, 26603, 'nama'),
#    (26873, 26877, 'nama'),
#    (27006, 27010, 'nama'),
#    (27113, 27119, 'nama'),
#    (27150, 27156, 'nama'),
#    (27163, 27167, 'nama'),
#    (27388, 27394, 'nama'),
#    (27401, 27407, 'nama'),
#    (27466, 27471, 'nama'),
#    (27472, 27477, 'nama'),
#    (27515, 27525, 'nama'),
#    (27588, 27593, 'nama'),
#    (27653, 27658, 'nama'),
#    (27659, 27664, 'nama'),
#    (27701, 27709, 'nama'),
#    (27710, 27714, 'nama'),
#    (27715, 27719, 'nama'),
#    (27751, 27761, 'nama'),
#    (27913, 27917, 'nama'),
#    (27918, 27928, 'nama'),
#    (27977, 27987, 'nama'),
#    (28026, 28030, 'nama'),
#    (28131, 28141, 'nama'),
#    (28184, 28188, 'nama'),
#    (28189, 28193, 'nama'),
#    (28235, 28245, 'nama'),
#    (28252, 28256, 'nama'),
#    (28300, 28310, 'nama'),
#    (28459, 28470, 'nama'),
#    (28539, 28544, 'nama'),
#    (28680, 28685, 'nama'),
#    (28727, 28732, 'nama'),
#    (28803, 28808, 'nama'),
#    (28869, 28874, 'nama'),
#    (28949, 28960, 'nama'),
#    (28997, 29002, 'nama'),
#    (29041, 29046, 'nama'),
#    (29181, 29217, 'nama'),
#    (29241, 29252, 'nama'),
#    (29465, 29476, 'nama'),
#    (29602, 29606, 'nama'),
#    (29607, 29615, 'nama'),
#    (29665, 29676, 'nama'),
#    (29864, 29869, 'nama'),
#    (30579, 30591, 'nama'),
#    (30615, 30619, 'nama'),
#    (30836, 30841, 'nama'),
#    (30842, 30847, 'nama'),
#    (31030, 31037, 'nama'),
#    (32672, 32677, 'nama'),
#    (32678, 32683, 'nama'),
#    (32948, 32955, 'nama'),
#    (32956, 32960, 'nama'),
#    (33031, 33038, 'nama'),
#    (33158, 33165, 'nama'),
#    (33395, 33398, 'nama'),
#    (33399, 33408, 'nama'),
#    (33412, 33418, 'nama'),
#    (33419, 33426, 'nama'),
#    (33430, 33435, 'nama'),
#    (33449, 33455, 'nama'),
#    (33502, 33508, 'nama'),
#    (33509, 33514, 'nama'),
#    (34053, 34061, 'nama'),
#    (34728, 34731, 'nama'),
#    (34732, 34741, 'nama'),
#    (34745, 34749, 'nama'),
#    (34750, 34757, 'nama'),
#    (35019, 35033, 'nama'),
#    (35151, 35156, 'nama'),
#    (35305, 35310, 'nama'),
#    (35851, 35856, 'nama'),
#    (36004, 36008, 'nama'),
#    (36291, 36297, 'nama'),
#    (36524, 36530, 'nama'),
#    (37671, 37676, 'nama'),
#    (37677, 37684, 'nama'),
#    (37814, 37819, 'nama'),
#    (37897, 37902, 'nama'),
#    (37963, 37968, 'nama'),
#    (38035, 38040, 'nama'),
#    (38069, 38074, 'nama'),
#    (38142, 38147, 'nama'),
#    (38371, 38376, 'nama'),
#    (38513, 38518, 'nama'),
#    (38565, 38570, 'nama'),
#    (38620, 38625, 'nama'),
#    (38822, 38827, 'nama'),
#    (38904, 38909, 'nama'),
#    (39017, 39022, 'nama'),
#    (40094, 40105, 'nama'),
#    (41324, 41328, 'nama'),
#    (41534, 41538, 'nama'),
#    (41769, 41773, 'nama'),
#    (42172, 42178, 'nama'),
#    (42478, 42484, 'nama'),
#    (42708, 42716, 'nama'),
#    (42970, 42978, 'nama'),
#    (43136, 43142, 'nama'),
#    (43705, 43714, 'nama'),
#    (43783, 43792, 'nama'),
#    (43881, 43890, 'nama'),
#    (44048, 44057, 'nama'),
#    (44139, 44148, 'nama'),
#    (44860, 44865, 'nama'),
#    (45037, 45042, 'nama'),
#    (45107, 45112, 'nama'),
#    (45442, 45449, 'nama'),
#    (45496, 45503, 'nama'),
#    (45777, 45781, 'nama'),
#    (47169, 47173, 'nama'),
#    (47298, 47302, 'nama'),
#    (48344, 48349, 'nama'),
#    (48439, 48444, 'nama'),
#    (48598, 48603, 'nama'),
#    (48784, 48790, 'nama'),
#    (48950, 48955, 'nama'),
#    (48983, 48993, 'nama'),
#    (48994, 49000, 'nama'),
#    (49142, 49146, 'nama'),
#    (49448, 49452, 'nama'),
#    (49581, 49585, 'nama'),
#    (49675, 49681, 'nama'),
#    (49865, 49871, 'nama'),
#    (49927, 49933, 'nama'),
#    (50063, 50069, 'nama'),
#    (50280, 50285, 'nama'),
#    (50533, 50541, 'nama'),
#    (50769, 50774, 'nama'),
#    (52597, 52601, 'nama'),
#    (55245, 55250, 'nama'),
#    (55427, 55432, 'nama'),
#    (55572, 55577, 'nama'),
#    (55662, 55666, 'nama'),
#    (55884, 55889, 'nama'),
#    (55894, 55898, 'nama'),
#    (55975, 55979, 'nama'),
#    (56140, 56144, 'nama'),
#    (56786, 56790, 'nama'),
#    (57413, 57417, 'nama'),
#    (58952, 58967, 'nama'),
#    (58971, 58978, 'nama'),
#    (59268, 59275, 'nama'),
#    (59512, 59519, 'nama'),
#    (59921, 59928, 'nama'),
#    (59929, 59936, 'nama'),
#    (60149, 60156, 'nama'),
#    (60205, 60219, 'nama'),
#    (60293, 60298, 'nama'),
#    (60340, 60345, 'nama'),
#    (60383, 60388, 'nama'),
#    (60503, 60508, 'nama'),
#    (60533, 60538, 'nama'),
#    (60732, 60737, 'nama'),
#    (60768, 60774, 'nama'),
#    (60921, 60927, 'nama'),
#    (60954, 60960, 'nama'),
#    (61072, 61078, 'nama'),
#    (61171, 61177, 'nama'),
#    (61310, 61316, 'nama'),
#    (61445, 61451, 'nama'),
#    (61452, 61458, 'nama'),
#    (61855, 61872, 'nama'),
#    (62435, 62447, 'nama'),
#    (62841, 62845, 'nama'),
#    (63142, 63146, 'nama'),
#    (63275, 63279, 'nama'),
#    (63383, 63391, 'nama'),
#    (63879, 63887, 'nama'),
#    (64058, 64066, 'nama'),
#    (64363, 64376, 'nama'),
#    (66010, 66024, 'nama'),
#    (66025, 66031, 'nama'),
#    (66201, 66207, 'nama'),
#    (66357, 66363, 'nama'),
#    (66473, 66479, 'nama'),
#    (67061, 67071, 'nama'),
#    (67734, 67739, 'nama'),
#    (68341, 68346, 'nama'),
#    (68746, 68756, 'nama'),
#    (70026, 70045, 'nama'),
#    (70257, 70262, 'nama'),
#    (70563, 70568, 'nama'),
#    (70930, 70935, 'nama'),
#    (70946, 70947, 'nama'),
#    (72325, 72340, 'nama'),
#    (72425, 72430, 'nama'),
#    (73050, 73061, 'nama'),
#    (73499, 73505, 'nama'),
#    (73746, 73752, 'nama'),
#    (73753, 73764, 'nama'),
#    (74265, 74269, 'nama'),
#    (75257, 75262, 'nama'),
#    (75546, 75551, 'nama'),
#    (75594, 75607, 'nama'),
#    (75943, 75948, 'nama'),
#    (76768, 76773, 'nama'),
#    (77057, 77062, 'nama'),
#    (77067, 77080, 'nama'),
#    (77453, 77458, 'nama'),
#    (78076, 78091, 'nama'),
#    (78235, 78244, 'nama'),
#    (78437, 78456, 'nama'),
#    (78542, 78547, 'nama'),
#    (78741, 78746, 'nama'),
#    (78770, 78775, 'nama'),
#    (79233, 79245, 'nama'),
#    (79322, 79326, 'nama'),
#    (79474, 79478, 'nama'),
#    (79501, 79523, 'nama'),
#    (79605, 79609, 'nama'),
#    (79660, 79664, 'nama'),
#    (79814, 79818, 'nama'),
#    (79878, 79882, 'nama'),
#    (79932, 79936, 'nama'),
#    (80404, 80415, 'nama'),
#    (80625, 80628, 'nama'),
#    (80680, 80683, 'nama'),
#    (80813, 80816, 'nama'),
#    (80872, 80875, 'nama'),
#    (81092, 81099, 'nama'),
#    (81157, 81160, 'nama'),
#    (81801, 81814, 'nama'),
#    (82048, 82052, 'nama'),
#    (82159, 82163, 'nama'),
#    (82285, 82289, 'nama'),
#    (82387, 82391, 'nama'),
#    (82788, 82798, 'nama'),
#    (83173, 83177, 'nama'),
#    (83381, 83395, 'nama'),
#    (83656, 83662, 'nama'),
#    (83845, 83851, 'nama'),
#    (84109, 84128, 'nama'),
#    (84217, 84223, 'nama'),
#    (84224, 84230, 'nama'),
#    (84475, 84481, 'nama'),
#    (84905, 84917, 'nama'),
#    (84971, 84976, 'nama'),
#    (85381, 85386, 'nama'),
#    (85756, 85769, 'nama'),
#    (85917, 85922, 'nama'),
#    (85948, 85953, 'nama'),
#    (86820, 86825, 'nama'),
#    (86848, 86853, 'nama'),
#    (87076, 87081, 'nama'),
#    (87509, 87514, 'nama'),
#    (87998, 88003, 'nama'),
#    (88165, 88170, 'nama'),
#    (88210, 88214, 'nama'),
#    (88225, 88229, 'nama'),
#    (89028, 89033, 'nama'),
#    (89250, 89254, 'nama'),
#    (89420, 89424, 'nama'),
#    (90090, 90094, 'nama'),
#    (90242, 90246, 'nama'),
#    (90265, 90269, 'nama'),
#    (90850, 90856, 'nama'),
#    (91185, 91196, 'nama'),
#    (91287, 91290, 'nama'),
#    (91436, 91439, 'nama'),
#    (91516, 91522, 'nama'),
#    (91535, 91538, 'nama'),
#    (92506, 92514, 'nama'),
#    (92515, 92518, 'nama'),
#    (92519, 92526, 'nama'),
#    (92538, 92546, 'nama'),
#    (93477, 93485, 'nama'),
#    (93670, 93678, 'nama'),
#    (93790, 93798, 'nama'),
#    (93909, 93917, 'nama'),
#    (93918, 93926, 'nama'),
#    (94295, 94299, 'nama'),
#    (94331, 94335, 'nama'),
#    (94398, 94402, 'nama'),
#    (94424, 94432, 'nama'),
#    (94433, 94436, 'nama'),
#    (94437, 94444, 'nama'),
#    (94445, 94449, 'nama'),
#    (94644, 94648, 'nama'),
#    (94892, 94896, 'nama'),
#    (95048, 95056, 'nama'),
#    (95057, 95060, 'nama'),
#    (95061, 95068, 'nama'),
#    (95080, 95088, 'nama'),
#    (95315, 95323, 'nama'),
#    (95435, 95443, 'nama'),
#    (95554, 95562, 'nama'),
#    (95563, 95571, 'nama'),
#    (96107, 96110, 'nama'),
#    (96152, 96155, 'nama'),
#    (96314, 96317, 'nama'),
#    (96334, 96337, 'nama'),
#    (96458, 96461, 'nama'),
#    (96462, 96465, 'nama'),
#    (96631, 96634, 'nama'),
#    (96649, 96652, 'nama'),
#    (96752, 96755, 'nama'),
#    (96795, 96802, 'nama'),
#    (96919, 96926, 'nama'),
#    (97238, 97254, 'nama'),
#    (97306, 97311, 'nama'),
#    (97599, 97604, 'nama'),
#    (97734, 97739, 'nama'),
#    (98063, 98068, 'nama'),
#    (98184, 98189, 'nama'),
#    (98317, 98322, 'nama'),
#    (98893, 98905, 'nama'),
#    (98991, 98995, 'nama'),
#    (99721, 99726, 'nama'),
#    (99842, 99847, 'nama'),
#    (100249, 100254, 'nama'),
#    (100269, 100274, 'nama'),
#    (100516, 100524, 'nama'),
#    (100525, 100531, 'nama'),
#    (100532, 100542, 'nama'),
#    (100845, 100853, 'nama'),
#    (101612, 101618, 'nama'),
#    (101619, 101623, 'nama'),
#    (101624, 101630, 'nama'),
#    (101631, 101636, 'nama'),
#    (101637, 101643, 'nama'),
#    (101862, 101868, 'nama'),
#    (102110, 102116, 'nama'),
#    (103227, 103244, 'nama'),
#    (103868, 103879, 'nama'),
#    (103898, 103904, 'nama'),
#    (104190, 104196, 'nama'),
#    (104676, 104688, 'nama'),
#    (104992, 105004, 'nama'),
#    (105055, 105067, 'nama'),
#    (105376, 105382, 'nama'),
#    (105571, 105583, 'nama'),
#    (105950, 105964, 'nama'),
#    (106000, 106004, 'nama'),
#    (106075, 106086, 'nama'),
#    (107620, 107625, 'nama'),
#    (107626, 107641, 'nama'),
#    (107950, 107962, 'nama'),
#    (110317, 110325, 'nama'),
#    (111010, 111018, 'nama'),
#    (111578, 111599, 'nama'),
#    (111850, 111861, 'nama'),
#    (112169, 112180, 'nama'),
#    (113041, 113055, 'nama'),
#    (113081, 113086, 'nama'),
#    (113133, 113138, 'nama'),
#    (113395, 113409, 'nama'),
#    (113446, 113451, 'nama'),
#    (113575, 113580, 'nama'),
#    (113602, 113607, 'nama'),
#    (113682, 113687, 'nama'),
#    (113892, 113897, 'nama'),
#    (113983, 113988, 'nama'),
#    (113998, 114003, 'nama'),
#    (114171, 114176, 'nama'),
#    (114204, 114215, 'nama'),
#    (114234, 114241, 'nama'),
#    (114333, 114340, 'nama'),
#    (114460, 114467, 'nama'),
#    (114607, 114614, 'nama'),
#    (114622, 114629, 'nama'),
#    (114630, 114635, 'nama'),
#    (114636, 114643, 'nama'),
#    (114644, 114650, 'nama'),
#    (114725, 114732, 'nama'),
#    (114901, 114908, 'nama'),
#    (114972, 114979, 'nama'),
#    (115041, 115048, 'nama'),
#    (115190, 115197, 'nama'),
#    (115295, 115302, 'nama'),
#    (115356, 115363, 'nama'),
#    (115390, 115404, 'nama'),
#    (115598, 115604, 'nama'),
#    (115722, 115728, 'nama'),
#    (115789, 115803, 'nama'),
#    (115918, 115924, 'nama'),
#    (116021, 116035, 'nama'),
#    (116119, 116133, 'nama'),
#    (116196, 116202, 'nama'),
#    (116254, 116268, 'nama'),
#    (116540, 116554, 'nama'),
#    (116587, 116601, 'nama'),
#    (116697, 116711, 'nama'),
#    (116776, 116782, 'nama'),
#    (116846, 116852, 'nama'),
#    (116924, 116930, 'nama'),
#    (117019, 117025, 'nama'),
#    (117077, 117091, 'nama'),
#    (117220, 117226, 'nama'),
#    (117309, 117315, 'nama'),
#    (117365, 117371, 'nama'),
#    (117658, 117664, 'nama'),
#    (117716, 117722, 'nama'),
#    (117859, 117865, 'nama'),
#    (117953, 117959, 'nama'),
#    (118029, 118035, 'nama'),
#    (118273, 118279, 'nama'),
#    (118290, 118296, 'nama'),
#    (118476, 118482, 'nama'),
#    (118521, 118527, 'nama'),
#    (118670, 118676, 'nama'),
#    (118745, 118751, 'nama'),
#    (118871, 118877, 'nama'),
#    (119037, 119043, 'nama'),
#    (119155, 119161, 'nama'),
#    (119249, 119255, 'nama'),
#    (119312, 119318, 'nama'),
#    (119384, 119390, 'nama'),
#    (119474, 119480, 'nama'),
#    (119627, 119633, 'nama'),
#    (119737, 119743, 'nama'),
#    (120029, 120035, 'nama'),
#    (120065, 120071, 'nama'),
#    (120194, 120206, 'nama'),
#    (120939, 120951, 'nama'),
#    (121267, 121279, 'nama'),
#    (122322, 122327, 'nama'),
#    (122328, 122333, 'nama'),
#    (122334, 122341, 'nama'),
#    (122457, 122462, 'nama'),
#    (123195, 123200, 'nama'),
#    (123201, 123205, 'nama'),
#    (123206, 123213, 'nama'),
#    (123449, 123454, 'nama'),
#    (123599, 123605, 'nama'),
#    (123770, 123776, 'nama'),
#    (123777, 123783, 'nama'),
#    (123937, 123943, 'nama'),
#    (125032, 125036, 'nama'),
#    (125037, 125053, 'nama'),
#    (125127, 125131, 'nama'),
#    (125146, 125150, 'nama'),
#    (125328, 125332, 'nama'),
#    (125989, 126004, 'nama'),
#    (126082, 126087, 'nama'),
#    (126197, 126202, 'nama')]}]

# %% [markdown]
# # Training

# %%
import spacy
from spacy import displacy
from spacy.util import minibatch, compounding
from spacy.util import decaying
from thinc.neural.optimizers import Adam
import random
from matplotlib import pyplot as plt

# %%
#@title custom_optimizer
def custom_optimizer(optimizer, learn_rate=0.0001, beta1=0.9, beta2=0.999, eps=1e-8, L2=1e-6, max_grad_norm=1.0):
    """
    Function to customizer spaCy default optimizer
    """
    
    optimizer.learn_rate = learn_rate
    optimizer.beta1 = beta1
    optimizer.beta2 = beta2
    optimizer.eps = eps
    optimizer.L2 = L2
    optimizer.max_grad_norm = max_grad_norm
    
    return optimizer

# %%
#@title train_spacy
def train_spacy(data, 
                iterations, 
                learn_rate=0.001, 
                beta1=0.9, 
                beta2=0.999, 
                eps=1e-8, 
                L2=1e-4, 
                max_grad_norm=1.0):
    """Load the model, set up the pipeline and train the entity recognizer."""
    
    # pada dasarnya, steps yang harus dilakukan untuk mentraining model NER di spaCy adalah sbb:
    # 1. instantiate blank model. blank model ini isi tasknya bisa bermacam2. tapi kita hanya butuh task untuk NER
    # 2. karena kita hanya butuh task NER, kita define task (pipe) bernama 'ner'
    # 3. setelah itu, labels yang sudah dipersiapkan di training data diadd ke dalam pipe ner tsb
    # 4. seperti yg disebutkan di poin 1 di atas, task model itu bisa bermacam2. tapi karena kita hanya butuh task NER, makanya task/pipe lain harus kita disable agar tidak ditraining
    # 5. definisikan grad descent optimizer, yaitu menggunakan Adam optimizer. pada method begin_training(), kita bisa mengganti hyperparameters pada model menggunakan arg "component_cfg" yang inputnya berbentuk dict of dicts {'<jenis pipe>': {'<hyperparameter>': value}}. kalau mau tau keys apa saja yg tersedia untuk hyperparameters tsb, setelah model selesai ditraining lalu disave, coba buka folder tempat model disave. lalu di dalam folder tsb, buka folder "ner". di dalam folder "ner", ada file bernama "cfg". file tsb melist semua hyperparameters yg tersedia pada model dan valuesnya.
    # 6. jika kita masih ingin tuning optimizernya, kita bisa menggunakan func custom_optimizer
    # 7. kalau kita mau menggunakan mekanisme dropout, kita bisa menggunakan func "decaying"
    # 8. mulai lakukan iterasi untuk training. iteration = epoch. kita melakukan training sejumlah n epochs. lalu tiap 1 epoch, kita melakukan training sebanyak m minibatches
    # 9. kita menggunakan func minibatch untuk mensplit training data sebanyak x size. func minibatch menerima input arg "size" dalam bentuk iterator, contohnya func compounding yg berfungsi untuk membuat iterator dengan args "start" sebagai nilai awal, "end" sebagai nilai max, dan "compound" sebagai kelipatan untuk dikali dengan nilai pada "Start". baca di sini https://spacy.io/api/top-level#util.minibatch
    # 10. func minibatch akan menghasilkan generator. dari generator tsb, kita melakukan update (forward propagation dan back propagation) pada model menggunakan method update()
    # 11. setelah seluruh minibatches pada 1 epoch/iteration selesai, proses pada epoch berikutnya akan dilakukan. terus seperti itu hingga mencapai epoch terakhir
        
    TRAIN_DATA = data
    nlp = spacy.blank('id')  # create blank Language class
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
       

    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        
        # additional lines
        optimizer = nlp.begin_training(component_cfg={"ner": {"conv_window": 3}})
        optimizer = custom_optimizer(optimizer, learn_rate=learn_rate)
        # Define decaying dropout
#         dropout = decaying(0.8, 0.2, 1e-6)
        
#         optimizer = nlp.begin_training()
        loss_list = []
        for itn in range(iterations):
            print("Starting iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            
            # batch up the examples using spaCy's minibatch
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 64.0, 1.001))
            
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
#                     drop=next(dropout),  # dropout - make it harder to memorise data
                    sgd= optimizer,
                    losses=losses)
            
#             for text, annotations in TRAIN_DATA:
#                 nlp.update(
#                     [text],  # batch of texts
#                     [annotations],  # batch of annotations
#                     drop=next(dropout),  # dropout - make it harder to memorise data
#                     sgd=optimizer,  # callable to update weights
#                     losses=losses)

            print(losses)
            loss_list.append(losses)
        
    return nlp, loss_list

# %%
# training model
model, loss = train_spacy([train_data], 147)
# Out:
# Starting iteration 0
# {'ner': 24958.663635253906}
# Starting iteration 1
# {'ner': 23673.10122680664}
# Starting iteration 2
# {'ner': 18056.428131103516}
# Starting iteration 3
# {'ner': 7866.727897644043}
# Starting iteration 4
# {'ner': 1727.479549407959}
# Starting iteration 5
# {'ner': 1329.6223487854004}
# Starting iteration 6
# {'ner': 1202.5654863119125}
# Starting iteration 7
# {'ner': 1293.9007015228271}
# Starting iteration 8
# {'ner': 1085.53819589247}
# Starting iteration 9
# {'ner': 1048.780572517775}
# Starting iteration 10
# {'ner': 1027.9419832229614}
# Starting iteration 11
# {'ner': 1008.2870588265359}
# Starting iteration 12
# {'ner': 1026.5825412317645}
# Starting iteration 13
# {'ner': 1013.7875793064013}
# Starting iteration 14
# {'ner': 923.2615041732788}
# Starting iteration 15
# {'ner': 745.1676126718521}
# Starting iteration 16
# {'ner': 670.9728589057922}
# Starting iteration 17
# {'ner': 641.4704284667969}
# Starting iteration 18
# {'ner': 887.7973392009735}
# Starting iteration 19
# {'ner': 811.7476596832275}
# Starting iteration 20
# {'ner': 910.5305142402649}
# Starting iteration 21
# {'ner': 2919.1014819145203}
# Starting iteration 22
# {'ner': 6196.885480880737}
# Starting iteration 23
# {'ner': 3328.9072036743164}
# Starting iteration 24
# {'ner': 5429.079132080078}
# Starting iteration 25
# {'ner': 4535.139450073242}
# Starting iteration 26
# {'ner': 2685.785675048828}
# Starting iteration 27
# {'ner': 1377.6388549804688}
# Starting iteration 28
# {'ner': 608.1165475845337}
# Starting iteration 29
# {'ner': 513.505428314209}
# Starting iteration 30
# {'ner': 393.5276401042938}
# Starting iteration 31
# {'ner': 424.8654556274414}
# Starting iteration 32
# {'ner': 344.1243518590927}
# Starting iteration 33
# {'ner': 340.53911662101746}
# Starting iteration 34
# {'ner': 344.82274997234344}
# Starting iteration 35
# {'ner': 250.16868715608143}
# Starting iteration 36
# {'ner': 254.55631146987434}
# Starting iteration 37
# {'ner': 145.1225222996436}
# Starting iteration 38
# {'ner': 376.45426893234253}
# Starting iteration 39
# {'ner': 247.74403846263885}
# Starting iteration 40
# {'ner': 171.76315867900848}
# Starting iteration 41
# {'ner': 142.99660562211648}
# Starting iteration 42
# {'ner': 132.14794978499413}
# Starting iteration 43
# {'ner': 142.95608246023767}
# Starting iteration 44
# {'ner': 148.33512753149262}
# Starting iteration 45
# {'ner': 123.81241625547409}
# Starting iteration 46
# {'ner': 133.41235628021786}
# Starting iteration 47
# {'ner': 126.5418552231456}
# Starting iteration 48
# {'ner': 111.45195660740137}
# Starting iteration 49
# {'ner': 108.90674877166748}
# Starting iteration 50
# {'ner': 120.82277554291034}
# Starting iteration 51
# {'ner': 104.15135903656483}
# Starting iteration 52
# {'ner': 113.95760428106416}
# Starting iteration 53
# {'ner': 264.12961146980524}
# Starting iteration 54
# {'ner': 523.1347055435181}
# Starting iteration 55
# {'ner': 2251.9247960969806}
# Starting iteration 56
# {'ner': 5406.573752403259}
# Starting iteration 57
# {'ner': 7379.094882965088}
# Starting iteration 58
# {'ner': 11383.154891967773}
# Starting iteration 59
# {'ner': 8501.370903015137}
# Starting iteration 60
# {'ner': 12749.980598449707}
# Starting iteration 61
# {'ner': 15576.043670654297}
# Starting iteration 62
# {'ner': 15828.815612792969}
# Starting iteration 63
# {'ner': 13259.259841918945}
# Starting iteration 64
# {'ner': 11313.700088500977}
# Starting iteration 65
# {'ner': 8122.587341308594}
# Starting iteration 66
# {'ner': 4403.772125244141}
# Starting iteration 67
# {'ner': 2319.0289974212646}
# Starting iteration 68
# {'ner': 1397.5348558425903}
# Starting iteration 69
# {'ner': 1037.3169379234314}
# Starting iteration 70
# {'ner': 651.7693450450897}
# Starting iteration 71
# {'ner': 315.66601675748825}
# Starting iteration 72
# {'ner': 283.61238019168377}
# Starting iteration 73
# {'ner': 306.2259886562824}
# Starting iteration 74
# {'ner': 235.53989919275045}
# Starting iteration 75
# {'ner': 174.53676130250096}
# Starting iteration 76
# {'ner': 152.14224322023802}
# Starting iteration 77
# {'ner': 146.97854934262796}
# Starting iteration 78
# {'ner': 254.0058877468109}
# Starting iteration 79
# {'ner': 329.4443949460983}
# Starting iteration 80
# {'ner': 359.1408105865121}
# Starting iteration 81
# {'ner': 275.957694420591}
# Starting iteration 82
# {'ner': 208.0104888677597}
# Starting iteration 83
# {'ner': 169.60873746871948}
# Starting iteration 84
# {'ner': 140.21630764007568}
# Starting iteration 85
# {'ner': 149.0351519237738}
# Starting iteration 86
# {'ner': 311.9417969491333}
# Starting iteration 87
# {'ner': 432.64280235767365}
# Starting iteration 88
# {'ner': 532.8084723949432}
# Starting iteration 89
# {'ner': 576.3141422271729}
# Starting iteration 90
# {'ner': 852.0391874313354}
# Starting iteration 91
# {'ner': 2108.1770009994507}
# Starting iteration 92
# {'ner': 6950.787877082825}
# Starting iteration 93
# {'ner': 10111.99331665039}
# Starting iteration 94
# {'ner': 12411.044189453125}
# Starting iteration 95
# {'ner': 14135.940979003906}
# Starting iteration 96
# {'ner': 17730.258514404297}
# Starting iteration 97
# {'ner': 17600.497497558594}
# Starting iteration 98
# {'ner': 11230.587615966797}
# Starting iteration 99
# {'ner': 5229.961654663086}
# Starting iteration 100
# {'ner': 1706.1015625}
# Starting iteration 101
# {'ner': 821.7128562927246}
# Starting iteration 102
# {'ner': 643.3676290512085}
# Starting iteration 103
# {'ner': 473.79522767663}
# Starting iteration 104
# {'ner': 218.2659747004509}
# Starting iteration 105
# {'ner': 200.62300980696455}
# Starting iteration 106
# {'ner': 255.5005079372786}
# Starting iteration 107
# {'ner': 220.1893461367581}
# Starting iteration 108
# {'ner': 157.18349527742248}
# Starting iteration 109
# {'ner': 127.61712874099612}
# Starting iteration 110
# {'ner': 191.62561609349177}
# Starting iteration 111
# {'ner': 320.82570481300354}
# Starting iteration 112
# {'ner': 639.5631093978882}
# Starting iteration 113
# {'ner': 1449.864559173584}
# Starting iteration 114
# {'ner': 2198.0168867111206}
# Starting iteration 115
# {'ner': 2593.937452316284}
# Starting iteration 116
# {'ner': 2559.4151344299316}
# Starting iteration 117
# {'ner': 2118.8056964874268}
# Starting iteration 118
# {'ner': 1335.5283946990967}
# Starting iteration 119
# {'ner': 910.7004482746124}
# Starting iteration 120
# {'ner': 906.462513923645}
# Starting iteration 121
# {'ner': 947.007640838623}
# Starting iteration 122
# {'ner': 1083.5958909988403}
# Starting iteration 123
# {'ner': 1713.6722302436829}
# Starting iteration 124
# {'ner': 759.5550003051758}
# Starting iteration 125
# {'ner': 979.7343487739563}
# Starting iteration 126
# {'ner': 1045.1482133865356}
# Starting iteration 127
# {'ner': 894.1971683502197}
# Starting iteration 128
# {'ner': 627.7363624572754}
# Starting iteration 129
# {'ner': 1135.360846042633}
# Starting iteration 130
# {'ner': 1359.0017638206482}
# Starting iteration 131
# {'ner': 1318.4305911660194}
# Starting iteration 132
# {'ner': 751.8494906425476}
# Starting iteration 133
# {'ner': 809.4904079437256}
# Starting iteration 134
# {'ner': 905.6535720825195}
# Starting iteration 135
# {'ner': 807.3790674209595}
# Starting iteration 136
# {'ner': 681.7940168380737}
# Starting iteration 137
# {'ner': 676.3685641288757}
# Starting iteration 138
# {'ner': 442.18788051605225}
# Starting iteration 139
# {'ner': 339.92737102508545}
# Starting iteration 140
# {'ner': 251.3192576766014}
# Starting iteration 141
# {'ner': 201.7593299150467}
# Starting iteration 142
# {'ner': 175.82326464354992}
# Starting iteration 143
# {'ner': 160.83939439058304}
# Starting iteration 144
# {'ner': 132.32777911471203}
# Starting iteration 145
# {'ner': 98.28429814820993}
# Starting iteration 146
# {'ner': 79.78211009968072}

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(12,8))
plt.plot([i['ner'] for i in loss])
plt.grid()
plt.title('Loss Function')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
# Save our trained model
link_save_model = "/content/drive/MyDrive/NER_Final/model/"
modelfile = input("Enter your Model Name: ")
model.to_disk(link_save_model + modelfile)
# Out:
# Enter your Model Name: model_who9
